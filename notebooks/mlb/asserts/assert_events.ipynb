# %%
import os
import sys
import json
from collections import defaultdict
import pandas as pd

import sys
sys.path.insert(0, '../../../pipelines/tasks/mlb/')

from common.pbp.models import Game
from common.pbp.context import BasesContext

# %%
games = []
for file in os.listdir('../../../data/mlb/pbp/2/'):
    with open(f'../../../data/mlb/pbp/2/{file}', 'r', encoding='UTF8') as pbp_input:
        game = Game(json.load(pbp_input))

    games.append(game)

# %%
import numpy as np

for game in games:
    for period in game.periods:
        for event in period.events:
            if len(event.pitch_events) > 0:
                print(game.id, period.id, event.id)
                print(np.array(event.pitches))
                print(event.entities.body)
                print()
# Out:
# 401354388 top-2 21
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=<Event id="20" desc="Arozarena to third on pickoff error by pitcher Velasquez." /> />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Díaz', 'type': 'lined out', 'at': 'right'}
#
# 401354388 bottom-3 35
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="34" desc="Engel stole second." /> /> />]
# {'outs': 1, 'player': 'Anderson', 'type': 'grounded out', 'at': 'first'}
#
# 401354388 bottom-5 58
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="56" desc="Engel stole second." /> /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="57" desc="Engel to third on wild pitch by Mazza." /> /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />]
# {'player': 'Anderson', 'type': 'walked', 'at': 'first'}
#
# 401354388 bottom-5 61
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="60" desc="Anderson stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 1]" pitch_event=None /> />]
# {'player': 'Abreu', 'type': 'walked', 'at': 'first'}
#
# 401354388 bottom-5 66
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 1]" pitch_event=<Event id="64" desc="Engel scored, Abreu to second on passed ball by Mejía, Anderson to third on passed ball by Mejía." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=<Event id="65" desc="Anderson out at home on runner's fielder's choice." /> /> />]
# {'player': 'Jalen Beeks', 'type': 'pitches', 'to': 'Eloy Jimenez', 'premature': True}
#
# 401354388 top-8 90
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=<Event id="89" desc="Margot to second on wild pitch by Severino." /> /> />]
# {'player': 'Kiermaier', 'type': 'hit by pitch', 'at': 'first'}
#
# 401354388 top-8 92
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=<Event id="91" desc="Kiermaier picked off second, Margot to third on pickoff error by pitcher Severino." /> />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Mejía', 'type': 'singled', 'at': 'right', 'moves': [{'player': 'Margot', 'type': 'advanced', 'at': 'home'}, {'player': 'Kiermaier', 'type': 'advanced', 'at': 'home'}, {'player': 'Mejía', 'type': 'advanced', 'at': 'second'}], 'runs': 2}
#
# 401354388 top-8 96
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="95" desc="Franco to third on wild pitch by Severino." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Arozarena', 'type': 'doubled', 'at': 'right center', 'moves': [{'player': 'Franco', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
#
# 401354388 top-8 98
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="97" desc="Arozarena to third on passed ball by Grandal." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'player': 'Choi', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401355960 bottom-2 20
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="19" desc="Urshela to second on wild pitch by Greinke." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />]
# {'type': 'fielding error', 'moves': [{'player': 'Celestino', 'type': 'advanced', 'at': 'first', 'how': 'fielding error', 'by': 'Witt Jr'}, {'player': 'Urshela', 'type': 'advanced', 'at': 'third', 'how': 'error'}]}
#
# 401355960 top-4 36
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="35" desc="Witt Jr. stole second." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Pasquantino', 'type': 'grounded out', 'at': 'shortstop', 'moves': [{'player': 'Witt Jr.', 'type': 'advanced', 'at': 'third'}]}
#
# 401356531 bottom-5 51
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="50" desc="Barnhart to second on wild pitch by Heasley." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Kreidler', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401355366 bottom-3 30
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="29" desc="Kwan stole second." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />]
# {'player': 'Rosario', 'type': 'doubled', 'at': 'right', 'moves': [{'player': 'Kwan', 'type': 'advanced', 'at': 'third'}]}
#
# 401355366 bottom-8 81
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="80" desc="Rosario stole second." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Naylor', 'type': 'grounded out', 'at': 'second'}
#
# 401355366 top-9 87
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="86" desc="Gordon to second on passed ball by Maile." /> /> />]
# {'outs': 1, 'player': 'Jeffers', 'type': 'flied out', 'at': 'left'}
#
# 401355366 bottom-10 116
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="115" desc="Palacios to third on wild pitch by Pagán." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />]
# {'player': 'Kwan', 'type': 'walked', 'at': 'first'}
#
# 401355366 bottom-10 121
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=<Event id="120" desc="Kwan scored, Rosario to third on passed ball by Jeffers." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />]
# {'player': 'Naylor', 'type': 'homered', 'at': 'left', 'runs': 2, 'moves': [{'player': 'Rosario', 'type': 'advanced', 'at': 'home'}], 'distance': 358}
#
# 401354473 top-3 28
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="27" desc="Anderson stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="8"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Grandal', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401354473 top-6 59
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="58" desc="Sheets to second on wild pitch by Winder." /> /> />]
# {'outs': 1, 'player': 'Vaughn', 'type': 'fouled out', 'at': 'first'}
#
# 401354473 bottom-8 90
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=<Event id="89" desc="Celestino to third on pickoff error by pitcher Graveman." /> />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />]
# {'player': 'Sanó', 'type': 'walked', 'at': 'first'}
#
# 401354473 bottom-10 113
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=<Event id="112" desc="Godoy to second on wild pitch by Hendriks, Gordon to third on wild pitch by Hendriks." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />]
# {'player': 'Buxton', 'type': 'homered', 'at': 'left', 'runs': 3, 'moves': [{'player': 'Gordon', 'type': 'advanced', 'at': 'home'}, {'player': 'Godoy', 'type': 'advanced', 'at': 'home'}], 'distance': 469}
#
# 401355491 top-6 67
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="66" desc="Giménez to second on wild pitch by Mills." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="8"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Jones', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401423181 top-1 6
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="5" desc="Melendez caught stealing second, catcher to second." /> /> />]
# {'player': 'Triston McKenzie', 'type': 'pitches', 'to': 'Edward Olivares', 'premature': True}
#
# 401423181 bottom-2 21
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="20" desc="González to second on wild pitch by Greinke." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />]
# {'player': 'Giménez', 'type': 'lined into double play', 'outs': 2, 'order': ['shortstop'], 'moves': [{'player': 'González', 'type': 'out', 'at': 'second'}]}
#
# 401423181 bottom-5 54
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=<Event id="53" desc="Brennan to second on wild pitch by Greinke, Kwan to third on wild pitch by Greinke." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Ramírez', 'type': 'grounded out', 'at': 'shortstop'}
#
# 401423181 top-6 59
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="58" desc="Witt Jr. stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="8"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Pasquantino', 'type': 'walked', 'at': 'first'}
#
# 401423181 top-6 63
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="62" desc="Pasquantino stole second." /> /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="8"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Dozier', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401423181 bottom-6 70
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="69" desc="Arias to second on wild pitch by Greinke." /> /> />]
# {'outs': 1, 'player': 'Bo Naylor', 'type': 'flied out', 'at': 'center'}
#
# 401423181 bottom-8 89
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="87" desc="Giménez stole second." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="88" desc="Giménez to third on wild pitch by Coleman." /> /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'player': 'Miller', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401355311 top-1 6
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="5" desc="Laureano stole second." /> /> />]
# {'player': 'Brown', 'type': 'singled', 'at': 'right', 'moves': [{'player': 'Kemp', 'type': 'advanced', 'at': 'home'}, {'player': 'Laureano', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
#
# 401355311 top-1 9
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="8" desc="Brown to third on wild pitch by Keller." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'player': 'Bethancourt', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401355311 bottom-1 15
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="14" desc="Benintendi to second on wild pitch by Koenig." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />]
# {'player': 'Olivares', 'type': "grounded into fielder's choice", 'at': 'third', 'moves': [{'player': 'Benintendi', 'type': 'advanced', 'at': 'third', 'how': 'interference', 'by': 'Bride'}]}
#
# 401355311 top-2 21
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=<Event id="20" desc="Andrus caught stealing second, catcher to second." /> /> />]
# {'outs': 1, 'player': 'Allen', 'type': 'lined out', 'at': 'second'}
#
# 401355311 bottom-5 68
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=<Event id="67" desc="Melendez to second on wild pitch by Puk, Benintendi to third on wild pitch by Puk." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />]
# {'player': 'Dozier', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401355311 bottom-8 110
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="109" desc="Isbel out at third on runner's fielder's choice." /> /> />]
# {'player': 'Benintendi', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
#
# 401355311 top-9 120
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=<Event id="119" desc="Bethancourt scored on Coleman wild pitch." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />]
# {'player': 'Allen', 'type': 'walked', 'at': 'first'}
#
# 401356301 bottom-7 80
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="79" desc="Thomas to second on wild pitch by López." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Pache', 'type': 'grounded out', 'at': 'shortstop'}
#
# 401355413 top-5 50
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="49" desc="Sheets to third on wild pitch by Long." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Moncada', 'type': 'grounded out', 'at': 'shortstop'}
#
# 401354306 top-6 55
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="54" desc="Devers to second on wild pitch by Barnes." /> /> />]
# {'outs': 1, 'player': 'Bogaerts', 'type': 'flied out', 'at': 'shortstop'}
#
# 401354306 top-8 77
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="76" desc="Hernández to second on wild pitch by Lange." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Devers', 'type': 'singled', 'at': 'center', 'moves': [{'player': 'Hernández', 'type': 'advanced', 'at': 'home', 'how': 'error'}, {'player': 'Devers', 'type': 'advanced', 'at': 'second', 'how': 'fielding error', 'by': 'Baddoo'}], 'runs': 1}
#
# 401356045 bottom-1 10
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="9" desc="Buxton stole second." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />]
# {'player': 'Miranda', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401356045 bottom-4 40
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="39" desc="Gordon caught stealing third, catcher to third." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />]
# {'outs': 1, 'player': 'León', 'type': 'lined out', 'at': 'left'}
#
# 401356045 top-6 57
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=<Event id="56" desc="Seager to second on wild pitch by Gray, Duran to third on wild pitch by Gray." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'García', 'type': 'grounded out', 'at': 'third'}
#
# 401355828 bottom-8 77
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="76" desc="Naylor stole second." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Gonzalez', 'type': 'grounded out', 'at': 'shortstop'}
#
# 401355828 top-9 89
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="88" desc="Díaz to third on wild pitch by Clase." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Mancini', 'type': 'grounded out', 'at': 'shortstop'}
#
# 401354556 bottom-7 70
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="69" desc="N. Allen stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Kemp', 'type': 'flied out', 'at': 'left'}
#
# 401355428 bottom-9 93
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="92" desc="Engel caught stealing second, catcher to shortstop." /> /> />]
# {'player': 'Emilio Pagan', 'type': 'pitches', 'to': 'Yoan Moncada', 'premature': True}
#
# 401355756 bottom-2 18
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="17" desc="Giménez stole second." /> /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />]
# {'player': 'Miller', 'type': 'homered', 'at': 'left', 'runs': 2, 'moves': [{'player': 'Giménez', 'type': 'advanced', 'at': 'home'}], 'distance': 398}
#
# 401355756 bottom-5 57
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="56" desc="Rosario to second on wild pitch by Holton." /> /> />]
# {'player': 'Naylor', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401355756 bottom-6 68
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="67" desc="Giménez stole third." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'player': 'Jones', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401355756 bottom-7 80
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="79" desc="Kwan stole second." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Rosario', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401355756 top-8 90
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="89" desc="McCarthy stole second, McCarthy safe at third on throwing error by catcher Hedges." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'player': 'Beer', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401355756 bottom-10 114
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
# ...
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="58" desc="Robert scored on throwing error by catcher Huff." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />]
# {'player': 'Abreu', 'type': 'walked', 'at': 'first'}
#
# 401355112 top-8 80
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="79" desc="García stole second." /> /> />]
# {'player': 'Calhoun', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401356047 top-8 87
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="8"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="9"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="10"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=<Event id="86" desc="Rivera scored, Walker to third on Weaver wild pitch." /> /> />]
# {'outs': 1, 'player': 'Varsho', 'type': 'flied out', 'at': 'shortstop'}
#
# 401356047 top-9 101
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=<Event id="100" desc="McCarthy stole third." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Thomas', 'type': "grounded into fielder's choice", 'at': 'second', 'moves': [{'player': 'C. Kelly', 'type': 'advanced', 'at': 'second'}, {'player': 'McCarthy', 'type': 'out', 'at': 'home'}], 'outs': 1}
#
# 401439776 bottom-2 19
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=<Event id="18" desc="Kiner-Falefa picked off first." /> />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />]
# {'player': 'Gonzalez', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401439776 bottom-7 72
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=<Event id="70" desc="Hicks picked off second." /> />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="71" desc="Kiner-Falefa to second on passed ball by Grandal." /> /> />
#  <Pitch id="8"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="9"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Trevino', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
#
# 401439776 top-9 92
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="90" desc="Vaughn to second on wild pitch by Chapman." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="91" desc="Vaughn to third on passed ball by Trevino." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Engel', 'type': 'doubled', 'at': 'left', 'moves': [{'player': 'Vaughn', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
#
# 401439776 top-9 96
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="95" desc="Engel to third on wild pitch by Marinaccio." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'player': 'Moncada', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401356211 top-8 84
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="83" desc="Kepler scored, Gordon to second on passed ball by Zavala." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'G. Sánchez', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401354386 top-6 55
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="54" desc="Pederson stole second." /> /> />]
# {'outs': 1, 'player': 'Flores', 'type': 'popped out', 'at': 'shortstop'}
#
# 401354386 top-6 59
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="58" desc="Duggar stole second." /> /> />]
# {'player': 'Casali', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401356092 bottom-2 22
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="21" desc="Thompson stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Semien', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401356092 bottom-3 36
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="35" desc="García stole second." /> /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Heim', 'type': 'popped out', 'at': 'third'}
#
# 401355714 bottom-4 45
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=<Event id="44" desc="Chang to second on a balk, Bethancourt to third on a balk." /> />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />                                                                            ]
# {'outs': 1, 'player': 'Díaz', 'type': 'grounded out', 'at': 'shortstop'}
#
# 401355714 top-5 51
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="50" desc="Kwan stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />]
# {'player': 'Ramírez', 'type': 'homered', 'at': 'left center', 'runs': 2, 'moves': [{'player': 'Kwan', 'type': 'advanced', 'at': 'home'}], 'distance': 402}
#
# 401354684 bottom-5 49
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="48" desc="Anderson stole second, Anderson safe at third on throwing error by catcher Hedges." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Moncada', 'type': 'grounded out', 'at': 'second'}
#
# 401355719 bottom-5 48
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="47" desc="Kim stole second." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Profar', 'type': 'flied out', 'at': 'center'}
#
# 401355719 bottom-6 66
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=<Event id="65" desc="Profar to second on wild pitch by Moran, Grisham to third on wild pitch by Moran." /> /> />]
# {'player': 'Machado', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}

# %%
g = games[0]

# %%
for game in games:
    for period in game.periods:

        context = BasesContext()

        print(game.id, period.id)

        for event in period.events:
            if event.entities.type in ['sub-p']:
                continue


            print(event.entities.body)
            state = context.play(event.entities)
            print(state.before, state.after)

            
            ##print(context.to_list(), event.last_pitch.result.bases if event.last_pitch else None)

        print()
# Out:
# 401354388 top-1
# {'player': 'B. Lowe', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Franco', 'type': 'infield single', 'at': 'shortstop'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Arozarena', 'type': 'singled', 'at': 'center', 'moves': [{'player': 'Franco', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'player': 'Choi', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Arozarena', 'type': 'advanced', 'at': 'second'}, {'player': 'Franco', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [1, 1, 1]
# {'player': 'Díaz', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Franco', 'type': 'advanced', 'at': 'home'}, {'player': 'Choi', 'type': 'advanced', 'at': 'second'}, {'player': 'Arozarena', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 1, 1] [1, 1, 1]
# {'player': 'J. Lowe', 'type': "grounded into fielder's choice", 'at': 'pitcher', 'moves': [{'player': 'Arozarena', 'type': 'advanced', 'at': 'home', 'how': 'fielding error', 'by': 'Velasquez'}, {'player': 'Díaz', 'type': 'advanced', 'at': 'second'}, {'player': 'Choi', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 1, 1] [1, 1, 1]
# {'player': 'Margot', 'type': 'singled', 'at': 'right center', 'moves': [{'player': 'Choi', 'type': 'advanced', 'at': 'home'}, {'player': 'J. Lowe', 'type': 'advanced', 'at': 'second'}, {'player': 'Díaz', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 1, 1] [1, 1, 1]
# {'player': 'Kiermaier', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Díaz', 'type': 'advanced', 'at': 'home'}, {'player': 'Margot', 'type': 'advanced', 'at': 'second'}, {'player': 'J. Lowe', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 1, 1] [1, 1, 1]
# {'player': 'Mejía', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 1, 1] [1, 1, 1]
# {'outs': 1, 'player': 'B. Lowe', 'type': 'flied out', 'at': 'left'}
# [1, 1, 1] [1, 1, 1]
#
# 401354388 bottom-1
# {'outs': 1, 'player': 'Anderson', 'type': 'flied out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Robert', 'type': 'flied out', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Abreu', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
#
# 401354388 top-2
# {'outs': 1, 'player': 'Franco', 'type': 'lined out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Arozarena', 'type': 'doubled', 'at': 'left'}
# [0, 0, 0] [0, 1, 0]
# {'player': 'Choi', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 1, 0] [0, 1, 0]
# {'player': 'Velasquez', 'type': 'pickoff error', 'moves': [{'player': 'Arozarena', 'type': 'advanced', 'at': 'third', 'how': 'pickoff error', 'by': 'Velasquez'}]}
# [0, 1, 0] [0, 0, 1]
# {'outs': 1, 'player': 'Díaz', 'type': 'lined out', 'at': 'right'}
# [0, 0, 1] [0, 0, 1]
#
# 401354388 bottom-2
# {'player': 'Grandal', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Jiménez', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Sheets', 'type': 'popped out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
#
# 401354388 top-3
# {'outs': 1, 'player': 'J. Lowe', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Margot', 'type': 'grounded out', 'at': 'catcher'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Kiermaier', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
#
# 401354388 bottom-3
# {'outs': 1, 'player': 'Harrison', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Burger', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Engel', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'type': 'stole', 'moves': [{'player': 'Engel', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Anderson', 'type': 'grounded out', 'at': 'first'}
# [0, 1, 0] [0, 1, 0]
#
# 401354388 top-4
# {'player': 'Mejía', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'B. Lowe', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Franco', 'type': 'grounded out', 'at': 'first'}
# [0, 0, 0] [0, 0, 0]
#
# 401354388 bottom-4
# {'outs': 1, 'player': 'Robert', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Abreu', 'type': 'singled', 'at': 'right'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Grandal', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Abreu', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'player': 'Jiménez', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Grandal', 'type': 'advanced', 'at': 'second'}, {'player': 'Abreu', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [1, 1, 1]
# {'player': 'Sheets', 'type': 'hit by pitch', 'at': 'first', 'moves': [{'player': 'Abreu', 'type': 'advanced', 'at': 'home'}, {'player': 'Jiménez', 'type': 'advanced', 'at': 'second'}, {'player': 'Grandal', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 1, 1] [1, 1, 1]
# {'player': 'Harrison', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 1, 1] [1, 1, 1]
# {'player': 'Burger', 'type': "grounded into fielder's choice", 'at': 'shortstop', 'moves': [{'player': 'Sheets', 'type': 'out', 'at': 'second'}], 'outs': 1}
# [1, 1, 1] [1, 1, 1]
#
# 401354388 top-5
# {'outs': 1, 'player': 'Arozarena', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Choi', 'type': 'lined out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Díaz', 'type': 'singled', 'at': 'right'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'J. Lowe', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
#
# 401354388 bottom-5
# {'player': 'Engel', 'type': 'singled', 'at': 'left'}
# [0, 0, 0] [1, 0, 0]
# {'type': 'stole', 'moves': [{'player': 'Engel', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'player': 'Mazza', 'type': 'wild pitch', 'moves': [{'player': 'Engel', 'type': 'advanced', 'at': 'third', 'how': 'wild pitch', 'by': 'Mazza'}]}
# [0, 1, 0] [0, 0, 1]
# {'player': 'Anderson', 'type': 'walked', 'at': 'first'}
# [0, 0, 1] [1, 0, 1]
# {'outs': 1, 'player': 'Robert', 'type': 'flied out', 'at': 'right'}
# [1, 0, 1] [1, 0, 1]
# {'type': 'stole', 'moves': [{'player': 'Anderson', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 1] [0, 1, 1]
# {'player': 'Abreu', 'type': 'walked', 'at': 'first'}
# [0, 1, 1] [1, 1, 1]
# {'outs': 1, 'player': 'Grandal', 'type': 'popped out', 'at': 'second'}
# [1, 1, 1] [1, 1, 1]
# {'player': 'Mejía', 'type': 'passed ball', 'moves': [{'player': 'Engel', 'type': 'advanced', 'at': 'home'}, {'player': 'Abreu', 'type': 'advanced', 'at': 'second', 'how': 'passed ball', 'by': 'Mejía'}, {'player': 'Anderson', 'type': 'advanced', 'at': 'third', 'how': 'passed ball', 'by': 'Mejía'}], 'runs': 1}
# [1, 1, 1] [0, 1, 1]
# {'type': "runner's fielder's choice", 'moves': [{'player': 'Anderson', 'type': 'out', 'at': 'home', 'how': "runner's fielder's choice"}], 'outs': 1}
# [0, 1, 1] [0, 1, 0]
# {'player': 'Jalen Beeks', 'type': 'pitches', 'to': 'Eloy Jimenez', 'premature': True}
# [0, 1, 0] [0, 1, 0]
#
# 401354388 top-6
# {'player': 'Margot', 'type': 'doubled', 'at': 'center'}
# [0, 0, 0] [0, 1, 0]
# {'player': 'Kiermaier', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 1, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Mejía', 'type': 'grounded out', 'at': 'shortstop', 'moves': [{'player': 'Margot', 'type': 'advanced', 'at': 'third'}]}
# [0, 1, 0] [0, 0, 1]
# {'outs': 1, 'player': 'B. Lowe', 'type': 'flied out', 'at': 'left'}
# [0, 0, 1] [0, 0, 1]
#
# 401354388 bottom-6
# {'outs': 1, 'player': 'Jiménez', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Sheets', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Harrison', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
#
# 401354388 top-7
# {'outs': 1, 'player': 'Franco', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Arozarena', 'type': 'grounded out', 'at': 'pitcher'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Choi', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Díaz', 'type': 'flied out', 'at': 'right'}
# [1, 0, 0] [1, 0, 0]
#
# 401354388 bottom-7
# {'outs': 1, 'player': 'Burger', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Engel', 'type': 'fouled out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Anderson', 'type': 'grounded out', 'at': 'pitcher'}
# [0, 0, 0] [0, 0, 0]
#
# 401354388 top-8
# {'outs': 1, 'player': 'J. Lowe', 'type': 'grounded out', 'at': 'first'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Margot', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Severino', 'type': 'wild pitch', 'moves': [{'player': 'Margot', 'type': 'advanced', 'at': 'second', 'how': 'wild pitch', 'by': 'Severino'}]}
# [1, 0, 0] [0, 1, 0]
# {'player': 'Kiermaier', 'type': 'hit by pitch', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'player': 'Severino', 'type': 'pickoff error', 'moves': [{'player': 'Kiermaier', 'type': 'out', 'at': 'second'}, {'player': 'Margot', 'type': 'advanced', 'at': 'third', 'how': 'pickoff error', 'by': 'Severino'}], 'outs': 1}
# [1, 1, 0] [0, 0, 1]
# {'player': 'Mejía', 'type': 'singled', 'at': 'right', 'moves': [{'player': 'Margot', 'type': 'advanced', 'at': 'home'}, {'player': 'Kiermaier', 'type': 'advanced', 'at': 'home'}, {'player': 'Mejía', 'type': 'advanced', 'at': 'second'}], 'runs': 2}
# [0, 0, 1] [0, 1, 0]
# {'outs': 1, 'player': 'B. Lowe', 'type': 'flied out', 'at': 'center'}
# [0, 1, 0] [0, 1, 0]
# {'player': 'Franco', 'type': 'doubled', 'at': 'left center', 'moves': [{'player': 'Mejía', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
# [0, 1, 0] [0, 1, 0]
# {'player': 'Severino', 'type': 'wild pitch', 'moves': [{'player': 'Franco', 'type': 'advanced', 'at': 'third', 'how': 'wild pitch', 'by': 'Severino'}]}
# [0, 1, 0] [0, 0, 1]
# {'player': 'Arozarena', 'type': 'doubled', 'at': 'right center', 'moves': [{'player': 'Franco', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
# [0, 0, 1] [0, 1, 0]
# {'player': 'Grandal', 'type': 'passed ball', 'moves': [{'player': 'Arozarena', 'type': 'advanced', 'at': 'third', 'how': 'passed ball', 'by': 'Grandal'}]}
# [0, 1, 0] [0, 0, 1]
# {'player': 'Choi', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 1] [0, 0, 1]
#
# 401354388 bottom-8
# {'outs': 1, 'player': 'Robert', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Abreu', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Grandal', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
#
# 401354388 top-9
# {'outs': 1, 'player': 'Díaz', 'type': 'grounded out', 'at': 'pitcher'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'J. Lowe', 'type': 'singled', 'at': 'right'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Margot', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'J. Lowe', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'player': 'Kiermaier', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'J. Lowe', 'type': 'advanced', 'at': 'home'}, {'player': 'Margot', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 1, 0] [1, 0, 1]
# {'player': 'Mejía', 'type': 'lined into double play', 'outs': 2, 'order': ['pitcher', 'first'], 'moves': [{'player': 'Kiermaier', 'type': 'out', 'at': 'first'}]}
# [1, 0, 1] [0, 0, 1]
#
# 401354388 bottom-9
# {'outs': 1, 'player': 'Jiménez', 'type': 'flied out', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Sheets', 'type': 'homered', 'at': 'right', 'runs': 1, 'distance': 348}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Harrison', 'type': 'lined out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Burger', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
#
# 401355960 top-1
# {'outs': 1, 'player': 'Melendez', 'type': 'lined out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Witt Jr.', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Perez', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
#
# 401355960 bottom-1
# {'player': 'Arraez', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Correa', 'type': 'singled', 'at': 'center', 'moves': [{'player': 'Arraez', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'outs': 1, 'player': 'Buxton', 'type': 'popped out', 'at': 'first'}
# [1, 1, 0] [1, 1, 0]
# {'player': 'Miranda', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [1, 1, 0] [1, 1, 0]
# {'player': 'Kepler', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [1, 1, 0] [1, 1, 0]
#
# 401355960 top-2
# {'player': 'Pasquantino', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Massey', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Taylor', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Pratto', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [1, 0, 0] [1, 0, 0]
#
# 401355960 bottom-2
# {'player': 'Urshela', 'type': 'singled', 'at': 'left'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Gordon', 'type': 'flied out', 'at': 'right'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Greinke', 'type': 'wild pitch', 'moves': [{'player': 'Urshela', 'type': 'advanced', 'at': 'second', 'how': 'wild pitch', 'by': 'Greinke'}]}
# [1, 0, 0] [0, 1, 0]
# {'type': 'fielding error', 'moves': [{'player': 'Celestino', 'type': 'advanced', 'at': 'first', 'how': 'fielding error', 'by': 'Witt Jr'}, {'player': 'Urshela', 'type': 'advanced', 'at': 'third', 'how': 'error'}]}
# [0, 1, 0] [1, 0, 1]
# {'player': 'León', 'type': 'sacrificed', 'at': 'pitcher', 'outs': 1, 'moves': [{'player': 'Urshela', 'type': 'advanced', 'at': 'home'}, {'player': 'Celestino', 'type': 'advanced', 'at': 'second'}], 'runs': 1}
# [1, 0, 1] [0, 1, 0]
# {'player': 'Arraez', 'type': 'singled', 'at': 'center', 'moves': [{'player': 'Celestino', 'type': 'advanced', 'at': 'home'}, {'player': 'Arraez', 'type': 'out', 'at': 'second'}], 'outs': 1, 'runs': 1}
# [0, 1, 0] [0, 0, 0]
#
# 401355960 top-3
# {'outs': 1, 'player': 'Isbel', 'type': 'grounded out', 'at': 'first'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Lopez', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Melendez', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
#
# 401355960 bottom-3
# {'player': 'Correa', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Buxton', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Miranda', 'type': 'singled', 'at': 'right'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Kepler', 'type': 'grounded out', 'at': 'first'}
# [1, 0, 0] [1, 0, 0]
#
# 401355960 top-4
# {'player': 'Witt Jr.', 'type': 'singled', 'at': 'right center'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Perez', 'type': 'lined out', 'at': 'left'}
# [1, 0, 0] [1, 0, 0]
# {'type': 'stole', 'moves': [{'player': 'Witt Jr.', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Pasquantino', 'type': 'grounded out', 'at': 'shortstop', 'moves': [{'player': 'Witt Jr.', 'type': 'advanced', 'at': 'third'}]}
# [0, 1, 0] [0, 0, 1]
# {'player': 'Massey', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 1] [0, 0, 1]
#
# 401355960 bottom-4
# {'outs': 1, 'player': 'Urshela', 'type': 'lined out', 'at': 'first'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Gordon', 'type': 'lined out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Celestino', 'type': 'homered', 'at': 'left', 'runs': 1, 'distance': 386}
# [0, 0, 0] [0, 0, 0]
# {'player': 'León', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
#
# 401355960 top-5
# {'player': 'Taylor', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Pratto', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Isbel', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
#
# 401355960 bottom-5
# {'outs': 1, 'player': 'Arraez', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Correa', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Buxton', 'type': 'singled', 'at': 'left'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Miranda', 'type': 'singled', 'at': 'center', 'moves': [{'player': 'Buxton', 'type': 'advanced', 'at': 'third'}]}
# [1, 0, 0] [1, 0, 1]
# {'outs': 1, 'player': 'Kepler', 'type': 'lined out', 'at': 'right'}
# [1, 0, 1] [1, 0, 1]
#
# 401355960 top-6
# {'player': 'Lopez', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Melendez', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Witt Jr.', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
#
# 401355960 bottom-6
# {'player': 'Urshela', 'type': 'singled', 'at': 'left'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Gordon', 'type': 'grounded out', 'at': 'first', 'moves': [{'player': 'Urshela', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Celestino', 'type': 'grounded out', 'at': 'second', 'moves': [{'player': 'Urshela', 'type': 'advanced', 'at': 'third'}]}
# [0, 1, 0] [0, 0, 1]
# {'outs': 1, 'player': 'León', 'type': 'flied out', 'at': 'left'}
# [0, 0, 1] [0, 0, 1]
#
# 401355960 top-7
# {'player': 'Perez', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Pasquantino', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'Perez', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'player': 'Massey', 'type': "grounded into fielder's choice", 'at': 'first', 'moves': [{'player': 'Pasquantino', 'type': 'out', 'at': 'second'}, {'player': 'Perez', 'type': 'advanced', 'at': 'third'}], 'outs': 1}
# [1, 1, 0] [1, 0, 1]
# {'player': 'Taylor', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 1] [1, 0, 1]
# {'player': 'Pratto', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [1, 0, 1] [1, 0, 1]
#
# 401355960 bottom-7
# {'player': 'Arraez', 'type': 'doubled', 'at': 'deep right'}
# [0, 0, 0] [0, 1, 0]
# {'player': 'Correa', 'type': 'walked', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'player': 'Buxton', 'type': "grounded into fielder's choice", 'at': 'pitcher', 'moves': [{'player': 'Correa', 'type': 'out', 'at': 'second'}, {'player': 'Arráez', 'type': 'advanced', 'at': 'third'}], 'outs': 1}
# [1, 1, 0] [1, 0, 1]
# {'player': 'Miranda', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Buxton', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 1] [1, 1, 1]
# {'player': 'Kepler', 'type': "grounded into fielder's choice", 'at': 'second', 'moves': [{'player': 'Arráez', 'type': 'advanced', 'at': 'home'}, {'player': 'Miranda', 'type': 'out', 'at': 'second'}, {'player': 'Buxton', 'type': 'advanced', 'at': 'third'}], 'outs': 1, 'runs': 1}
# [1, 1, 1] [1, 0, 1]
# {'player': 'Urshela', 'type': 'singled', 'at': 'center', 'moves': [{'player': 'Buxton', 'type': 'advanced', 'at': 'home'}, {'player': 'Kepler', 'type': 'advanced', 'at': 'second'}], 'runs': 1}
# [1, 0, 1] [1, 1, 0]
# {'player': 'Gordon', 'type': 'doubled', 'at': 'right', 'moves': [{'player': 'Kepler', 'type': 'advanced', 'at': 'home'}, {'player': 'Urshela', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 1, 0] [0, 1, 1]
# {'player': 'Celestino', 'type': 'walked', 'at': 'first'}
# [0, 1, 1] [1, 1, 1]
# {'outs': 1, 'player': 'León', 'type': 'fouled out', 'at': 'second'}
# [1, 1, 1] [1, 1, 1]
#
# 401355960 top-8
# {'player': 'Isbel', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Lopez', 'type': 'infield single', 'at': 'third'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Melendez', 'type': 'lined into double play', 'outs': 2, 'order': ['first'], 'moves': [{'player': 'Lopez', 'type': 'out', 'at': 'first'}]}
# [1, 0, 0] [0, 0, 0]
#
# 401355960 bottom-8
# {'player': 'Garcia', 'type': 'sub-f', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'type': 'throwing error', 'moves': [{'player': 'Arraez', 'type': 'advanced', 'at': 'first', 'how': 'throwing error', 'by': 'Massey'}]}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Correa', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Buxton', 'type': 'singled', 'at': 'left center', 'moves': [{'player': 'Arraez', 'type': 'advanced', 'at': 'third'}]}
# [1, 0, 0] [1, 0, 1]
# {'player': 'Miranda', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'Arraez', 'type': 'advanced', 'at': 'home'}, {'player': 'Buxton', 'type': 'advanced', 'at': 'second'}], 'runs': 1}
# [1, 0, 1] [1, 1, 0]
# {'player': 'Kepler', 'type': "grounded into fielder's choice", 'at': 'first', 'moves': [{'player': 'Miranda', 'type': 'out', 'at': 'second'}, {'player': 'Buxton', 'type': 'advanced', 'at': 'third'}], 'outs': 1}
# [1, 1, 0] [1, 0, 1]
# {'player': 'Urshela', 'type': 'singled', 'at': 'right', 'moves': [{'player': 'Buxton', 'type': 'advanced', 'at': 'home'}, {'player': 'Kepler', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 0, 1] [1, 0, 1]
# {'player': 'Gordon', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'Kepler', 'type': 'advanced', 'at': 'home'}, {'player': 'Urshela', 'type': 'advanced', 'at': 'second'}], 'runs': 1}
# [1, 0, 1] [1, 1, 0]
# {'player': 'Celestino', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 1, 0] [1, 1, 0]
#
# 401355960 top-9
# {'player': "O'Hearn", 'type': 'sub-f', 'for': 'Witt Jr'}
# [0, 0, 0] [0, 0, 0]
# {'player': "O'Hearn", 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Perez', 'type': 'flied out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Pasquantino', 'type': 'singled', 'at': 'right'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Massey', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [1, 0, 0] [1, 0, 0]
#
# 401356531 top-1
# {'player': 'Melendez', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Witt Jr.', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Perez', 'type': 'flied out', 'at': 'right'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Pasquantino', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Melendez', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'outs': 1, 'player': 'Olivares', 'type': 'grounded out', 'at': 'third'}
# [1, 1, 0] [1, 1, 0]
#
# 401356531 bottom-1
# {'outs': 1, 'player': 'Baddoo', 'type': 'flied out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Greene', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Báez', 'type': 'flied out', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
#
# 401356531 top-2
# {'outs': 1, 'player': 'Dozier', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Taylor', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Eaton', 'type': 'sacrificed', 'at': 'pitcher', 'outs': 1, 'moves': [{'player': 'Taylor', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Lopez', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 1, 0] [0, 1, 0]
#
# 401356531 bottom-2
# {'outs': 1, 'player': 'H. Castro', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Schoop', 'type': 'lined out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'W. Castro', 'type': 'homered', 'at': 'right', 'runs': 1, 'distance': 376}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Candelario', 'type': 'flied out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
#
# 401356531 top-3
# {'player': 'Melendez', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Witt Jr.', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'type': 'throwing error', 'moves': [{'player': 'Perez', 'type': 'advanced', 'at': 'first', 'how': 'throwing error', 'by': 'Rodriguez'}]}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Pasquantino', 'type': 'singled', 'at': 'deep right', 'moves': [{'player': 'Perez', 'type': 'advanced', 'at': 'third'}]}
# [1, 0, 0] [1, 0, 1]
# {'outs': 1, 'player': 'Olivares', 'type': 'flied out', 'at': 'right'}
# [1, 0, 1] [1, 0, 1]
#
# 401356531 bottom-3
# {'player': 'Barnhart', 'type': 'singled', 'at': 'right center'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Kreidler', 'type': 'flied out', 'at': 'center'}
# [1, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Baddoo', 'type': 'grounded out', 'at': 'third', 'moves': [{'player': 'Barnhart', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Greene', 'type': 'grounded out', 'at': 'first'}
# [0, 1, 0] [0, 1, 0]
#
# 401356531 top-4
# {'player': 'Dozier', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Taylor', 'type': 'infield single', 'at': 'pitcher'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Eaton', 'type': "grounded into fielder's choice", 'at': 'first', 'moves': [{'player': 'Taylor', 'type': 'out', 'at': 'second'}], 'outs': 1}
# [1, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Lopez', 'type': 'grounded out', 'at': 'second'}
# [1, 0, 0] [1, 0, 0]
#
# 401356531 bottom-4
# {'outs': 1, 'player': 'Báez', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'H. Castro', 'type': 'grounded out', 'at': 'catcher'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Schoop', 'type': 'hit by pitch', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'W. Castro', 'type': 'doubled', 'at': 'left', 'moves': [{'player': 'Schoop', 'type': 'advanced', 'at': 'third'}]}
# [1, 0, 0] [0, 1, 1]
# {'player': 'Reyes', 'type': 'sub-f', 'for': 'W. Castro'}
# [0, 1, 1] [0, 1, 1]
# {'outs': 1, 'player': 'Candelario', 'type': 'flied out', 'at': 'left'}
# [0, 1, 1] [0, 1, 1]
#
# 401356531 top-5
# {'player': 'Reyes', 'type': 'sub-f', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Melendez', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Witt Jr.', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Perez', 'type': 'popped out', 'at': 'first'}
# [0, 0, 0] [0, 0, 0]
#
# 401356531 bottom-5
# {'player': 'Barnhart', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Heasley', 'type': 'wild pitch', 'moves': [{'player': 'Barnhart', 'type': 'advanced', 'at': 'second', 'how': 'wild pitch', 'by': 'Heasley'}]}
# [1, 0, 0] [0, 1, 0]
# {'player': 'Kreidler', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 1, 0] [0, 1, 0]
# {'type': 'fielding error', 'moves': [{'player': 'Barnhart', 'type': 'advanced', 'at': 'home'}, {'player': 'Baddoo', 'type': 'advanced', 'at': 'first', 'how': 'fielding error', 'by': 'Pasquantino'}], 'runs': 1}
# [0, 1, 0] [1, 0, 0]
# {'player': 'Greene', 'type': 'doubled', 'at': 'deep right', 'moves': [{'player': 'Baddoo', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
# [1, 0, 0] [0, 1, 0]
# {'player': 'Báez', 'type': 'homered', 'at': 'left', 'runs': 2, 'moves': [{'player': 'Greene', 'type': 'advanced', 'at': 'home'}], 'distance': 379}
# [0, 1, 0] [0, 0, 0]
# {'outs': 1, 'player': 'H. Castro', 'type': 'grounded out', 'at': 'first'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Schoop', 'type': 'doubled', 'at': 'left'}
# [0, 0, 0] [0, 1, 0]
# {'player': 'Reyes', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 1, 0] [0, 1, 0]
#
# 401356531 top-6
# {'outs': 1, 'player': 'Pasquantino', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Olivares', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Dozier', 'type': 'tripled', 'at': 'left'}
# [0, 0, 0] [0, 0, 1]
# {'outs': 1, 'player': 'Taylor', 'type': 'flied out', 'at': 'right'}
# [0, 0, 1] [0, 0, 1]
#
# 401356531 bottom-6
# {'player': 'Waters', 'type': 'sub-f', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Candelario', 'type': 'doubled', 'at': 'deep right center'}
# [0, 0, 0] [0, 1, 0]
# {'player': 'Barnhart', 'type': 'singled', 'at': 'center', 'moves': [{'player': 'Candelario', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
# [0, 1, 0] [1, 0, 0]
# {'player': 'Kreidler', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Baddoo', 'type': 'lined out', 'at': 'left'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Greene', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
#
# 401356531 top-7
# {'player': 'Eaton', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Lopez', 'type': 'grounded into double play', 'outs': 2, 'order': ['first', 'shortstop'], 'moves': [{'player': 'Eaton', 'type': 'out', 'at': 'second'}]}
# [1, 0, 0] [0, 0, 0]
# {'player': 'Melendez', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Witt Jr.', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Melendez', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'outs': 1, 'player': 'Perez', 'type': 'grounded out', 'at': 'third'}
# [1, 1, 0] [1, 1, 0]
#
# 401356531 bottom-7
# {'player': 'Rivero', 'type': 'sub-f'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Báez', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'H. Castro', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Báez', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'player': 'Schoop', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'H. Castro', 'type': 'advanced', 'at': 'second'}, {'player': 'Báez', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [1, 1, 1]
# {'player': 'Reyes', 'type': 'hit by pitch', 'at': 'first', 'moves': [{'player': 'Báez', 'type': 'advanced', 'at': 'home'}, {'player': 'Schoop', 'type': 'advanced', 'at': 'second'}, {'player': 'H. Castro', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 1, 1] [1, 1, 1]
# {'player': 'Candelario', 'type': 'sacrifice fly', 'at': 'center', 'outs': 1, 'moves': [{'player': 'H. Castro', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
# [1, 1, 1] [1, 1, 0]
# {'player': 'Barnhart', 'type': 'doubled', 'at': 'deep right', 'moves': [{'player': 'Schoop', 'type': 'advanced', 'at': 'home'}, {'player': 'Reyes', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 1, 0] [0, 1, 1]
# {'player': 'Kreidler', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'Reyes', 'type': 'advanced', 'at': 'home'}, {'player': 'Barnhart', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [0, 1, 1] [1, 0, 1]
# {'outs': 1, 'player': 'Baddoo', 'type': 'popped out', 'at': 'third'}
# [1, 0, 1] [1, 0, 1]
# {'player': 'Clemens', 'type': 'sub-f', 'for': 'Greene'}
# [1, 0, 1] [1, 0, 1]
# {'outs': 1, 'player': 'Clemens', 'type': 'flied out', 'at': 'left'}
# [1, 0, 1] [1, 0, 1]
#
# 401356531 top-8
# {'player': 'Clemens', 'type': 'sub-f', 'at': 'first'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'H. Castro', 'type': 'sub-f', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Kreidler', 'type': 'sub-f', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Pasquantino', 'type': 'singled', 'at': 'left'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Waters', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Pasquantino', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'player': "O'Hearn", 'type': 'sub-f', 'for': 'Dozier'}
# [1, 1, 0] [1, 1, 0]
# {'player': "O'Hearn", 'type': 'doubled', 'at': 'left', 'moves': [{'player': 'Waters', 'type': 'advanced', 'at': 'home'}, {'player': 'Pasquantino', 'type': 'advanced', 'at': 'home'}], 'runs': 2}
# [1, 1, 0] [0, 1, 0]
# {'player': 'Isbel', 'type': 'sub-f', 'for': 'Taylor'}
# [0, 1, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Isbel', 'type': 'popped out', 'at': 'shortstop'}
# [0, 1, 0] [0, 1, 0]
# {'player': 'Eaton', 'type': 'doubled', 'at': 'right center', 'moves': [{'player': "O'Hearn", 'type': 'advanced', 'at': 'home'}], 'runs': 1}
# [0, 1, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Lopez', 'type': 'popped out', 'at': 'shortstop'}
# [0, 1, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Rivero', 'type': 'flied out', 'at': 'right'}
# [0, 1, 0] [0, 1, 0]
#
# 401356531 bottom-8
# {'player': 'Haase', 'type': 'sub-f', 'for': 'Báez'}
# [0, 0, 0] [0, 0, 0]
# {'player': "O'Hearn", 'type': 'sub-f', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Isbel', 'type': 'sub-f', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Haase', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'H. Castro', 'type': 'flied out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Schoop', 'type': 'singled', 'at': 'right center'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Reyes', 'type': 'flied out', 'at': 'center'}
# [1, 0, 0] [1, 0, 0]
#
# 401356531 top-9
# {'player': 'Haase', 'type': 'sub-f', 'at': 'designated hitter'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Witt Jr.', 'type': 'singled', 'at': 'shallow left center'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Perez', 'type': 'lined out', 'at': 'third'}
# [1, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Pasquantino', 'type': 'flied out', 'at': 'right'}
# [1, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Waters', 'type': 'grounded out', 'at': 'first'}
# [1, 0, 0] [1, 0, 0]
#
# 401355366 top-1
# {'outs': 1, 'player': 'Arraez', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Miranda', 'type': 'grounded out', 'at': 'pitcher'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Polanco', 'type': 'flied out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
#
# 401355366 bottom-1
# {'player': 'Kwan', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Rosario', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'Kwan', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'player': 'Ramírez', 'type': 'singled', 'at': 'right', 'moves': [{'player': 'Rosario', 'type': 'advanced', 'at': 'second'}, {'player': 'Kwan', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [1, 1, 1]
# {'outs': 1, 'player': 'Naylor', 'type': 'flied out', 'at': 'center'}
# [1, 1, 1] [1, 1, 1]
# {'player': 'Reyes', 'type': "grounded into fielder's choice", 'at': 'shortstop', 'moves': [{'player': 'Kwan', 'type': 'advanced', 'at': 'home', 'how': 'error'}, {'player': 'Rosario', 'type': 'advanced', 'at': 'home'}, {'player': 'Ramírez', 'type': 'out', 'at': 'second'}, {'player': 'Reyes', 'type': 'advanced', 'at': 'second', 'how': 'throwing error', 'by': 'Arraez'}], 'outs': 1, 'runs': 2}
# [1, 1, 1] [0, 1, 0]
# {'outs': 1, 'player': 'Giménez', 'type': 'flied out', 'at': 'right'}
# [0, 1, 0] [0, 1, 0]
#
# 401355366 top-2
# {'player': 'Kepler', 'type': 'infield single', 'at': 'second'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Sánchez', 'type': "grounded into fielder's choice", 'at': 'shortstop', 'moves': [{'player': 'Kepler', 'type': 'out', 'at': 'second'}], 'outs': 1}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Kirilloff', 'type': 'doubled', 'at': 'left', 'moves': [{'player': 'Sánchez', 'type': 'advanced', 'at': 'third'}]}
# [1, 0, 0] [0, 1, 1]
# {'outs': 1, 'player': 'Urshela', 'type': 'grounded out', 'at': 'pitcher'}
# [0, 1, 1] [0, 1, 1]
# {'outs': 1, 'player': 'Jeffers', 'type': 'grounded out', 'at': 'third'}
# [0, 1, 1] [0, 1, 1]
#
# 401355366 bottom-2
# {'outs': 1, 'player': 'Gonzalez', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Maile', 'type': 'lined out', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Straw', 'type': 'flied out', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
#
# 401355366 top-3
# {'outs': 1, 'player': 'Celestino', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Arraez', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Miranda', 'type': 'singled', 'at': 'left center'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Polanco', 'type': 'grounded out', 'at': 'first'}
# [1, 0, 0] [1, 0, 0]
#
# 401355366 bottom-3
# {'player': 'Kwan', 'type': 'singled', 'at': 'left'}
# [0, 0, 0] [1, 0, 0]
# {'type': 'stole', 'moves': [{'player': 'Kwan', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'player': 'Rosario', 'type': 'doubled', 'at': 'right', 'moves': [{'player': 'Kwan', 'type': 'advanced', 'at': 'third'}]}
# [0, 1, 0] [0, 1, 1]
# {'outs': 1, 'player': 'Ramírez', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 1, 1] [0, 1, 1]
# {'player': 'Naylor', 'type': 'sacrifice fly', 'at': 'left', 'outs': 1, 'moves': [{'player': 'Kwan', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
# [0, 1, 1] [0, 1, 0]
# {'player': 'Reyes', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 1, 0] [0, 1, 0]
#
# 401355366 top-4
# {'outs': 1, 'player': 'Kepler', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Sánchez', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Kirilloff', 'type': 'singled', 'at': 'left'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Urshela', 'type': "grounded into fielder's choice", 'at': 'third', 'moves': [{'player': 'Kirilloff', 'type': 'out', 'at': 'second'}], 'outs': 1}
# [1, 0, 0] [1, 0, 0]
#
# 401355366 bottom-4
# {'outs': 1, 'player': 'Giménez', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Gonzalez', 'type': 'fouled out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Maile', 'type': 'flied out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
#
# 401355366 top-5
# {'player': 'Jeffers', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Celestino', 'type': 'doubled', 'at': 'right'}
# [0, 0, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Arraez', 'type': 'grounded out', 'at': 'second', 'moves': [{'player': 'Celestino', 'type': 'advanced', 'at': 'third'}]}
# [0, 1, 0] [0, 0, 1]
# {'outs': 1, 'player': 'Miranda', 'type': 'flied out', 'at': 'left'}
# [0, 0, 1] [0, 0, 1]
#
# 401355366 bottom-5
# {'outs': 1, 'player': 'Straw', 'type': 'flied out', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Kwan', 'type': 'doubled', 'at': 'left'}
# [0, 0, 0] [0, 1, 0]
# {'player': 'Rosario', 'type': 'walked', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'player': 'Ramírez', 'type': 'lined into double play', 'outs': 2, 'order': ['first'], 'moves': [{'player': 'Rosario', 'type': 'out', 'at': 'first'}]}
# [1, 1, 0] [0, 1, 0]
#
# 401355366 top-6
# {'outs': 1, 'player': 'Polanco', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Kepler', 'type': 'flied out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Sánchez', 'type': 'doubled', 'at': 'deep center'}
# [0, 0, 0] [0, 1, 0]
# {'player': 'Kirilloff', 'type': 'homered', 'at': 'right center', 'runs': 2, 'moves': [{'player': 'Sánchez', 'type': 'advanced', 'at': 'home'}], 'distance': 403}
# [0, 1, 0] [0, 0, 0]
# {'player': 'Urshela', 'type': 'homered', 'at': 'left', 'runs': 1, 'distance': 379}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Jeffers', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
#
# 401355366 bottom-6
# {'player': 'Naylor', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Reyes', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Giménez', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
#
# 401355366 top-7
# {'outs': 1, 'player': 'Celestino', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Arraez', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Miranda', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
#
# 401355366 bottom-7
# {'outs': 1, 'player': 'Gonzalez', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Maile', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Straw', 'type': 'lined out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
#
# 401355366 top-8
# {'outs': 1, 'player': 'Polanco', 'type': 'flied out', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Kepler', 'type': 'grounded out', 'at': 'first'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Sánchez', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
#
# 401355366 bottom-8
# {'outs': 1, 'player': 'Kwan', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Rosario', 'type': 'infield single', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Ramírez', 'type': 'popped out', 'at': 'right'}
# [1, 0, 0] [1, 0, 0]
# {'type': 'stole', 'moves': [{'player': 'Rosario', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Naylor', 'type': 'grounded out', 'at': 'second'}
# [0, 1, 0] [0, 1, 0]
#
# 401355366 top-9
# {'outs': 1, 'player': 'Kirilloff', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Urshela', 'type': 'singled', 'at': 'right'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Gordon', 'type': 'sub-f', 'for': 'Urshela'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Maile', 'type': 'passed ball', 'moves': [{'player': 'Gordon', 'type': 'advanced', 'at': 'second', 'how': 'passed ball', 'by': 'Maile'}]}
# [1, 0, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Jeffers', 'type': 'flied out', 'at': 'left'}
# [0, 1, 0] [0, 1, 0]
# {'player': 'Buxton', 'type': 'sub-f', 'for': 'Celestino'}
# [0, 1, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Buxton', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 1, 0] [0, 1, 0]
#
# 401355366 bottom-9
# {'player': 'Miranda', 'type': 'sub-f', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Kirilloff', 'type': 'sub-f', 'at': 'first'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Gordon', 'type': 'sub-f', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Buxton', 'type': 'sub-f', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Reyes', 'type': 'fouled out', 'at': 'first'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Giménez', 'type': 'singled', 'at': 'left'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Gonzalez', 'type': "grounded into fielder's choice", 'at': 'shortstop', 'moves': [{'player': 'Giménez', 'type': 'out', 'at': 'second'}], 'outs': 1}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Palacios', 'type': 'sub-f', 'for': 'Maile'}
# [1, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Palacios', 'type': 'popped out', 'at': 'shortstop'}
# [1, 0, 0] [1, 0, 0]
#
# 401355366 top-10
# {'player': 'Kwan', 'type': 'sub-f', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'León', 'type': 'sub-f'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Palacios', 'type': 'sub-f', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Arraez', 'type': 'fouled out', 'at': 'left', 'moves': [{'player': 'Buxton', 'type': 'advanced', 'at': 'third'}]}
# [0, 0, 0] [0, 0, 1]
# {'player': 'Correa', 'type': 'sub-f', 'for': 'Miranda'}
# [0, 0, 1] [0, 0, 1]
# {'player': 'Correa', 'type': 'singled', 'at': 'right', 'moves': [{'player': 'Buxton', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
# [0, 0, 1] [1, 0, 0]
# {'player': 'Polanco', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Kepler', 'type': 'homered', 'at': 'right', 'runs': 2, 'moves': [{'player': 'Correa', 'type': 'advanced', 'at': 'home'}], 'distance': 398}
# [1, 0, 0] [0, 0, 0]
# {'player': 'Sánchez', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
#
# 401355366 bottom-10
# {'player': 'Arraez', 'type': 'sub-f', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Correa', 'type': 'sub-f', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Polanco', 'type': 'sub-f', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Miller', 'type': 'sub-f', 'for': 'Straw'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Miller', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Pagán', 'type': 'wild pitch', 'moves': [{'player': 'Palacios', 'type': 'advanced', 'at': 'third', 'how': 'wild pitch', 'by': 'Pagán'}]}
# [0, 0, 0] [0, 0, 1]
# {'player': 'Kwan', 'type': 'walked', 'at': 'first'}
# [0, 0, 1] [1, 0, 1]
# {'player': 'Rosario', 'type': 'doubled', 'at': 'left', 'moves': [{'player': 'Palacios', 'type': 'advanced', 'at': 'home'}, {'player': 'Kwan', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 0, 1] [0, 1, 1]
# {'outs': 1, 'player': 'Ramírez', 'type': 'lined out', 'at': 'center'}
# [0, 1, 1] [0, 1, 1]
# {'player': 'Jeffers', 'type': 'passed ball', 'moves': [{'player': 'Kwan', 'type': 'advanced', 'at': 'home'}, {'player': 'Rosario', 'type': 'advanced', 'at': 'third', 'how': 'passed ball', 'by': 'Jeffers'}], 'runs': 1}
# [0, 1, 1] [0, 0, 1]
# {'player': 'Naylor', 'type': 'homered', 'at': 'left', 'runs': 2, 'moves': [{'player': 'Rosario', 'type': 'advanced', 'at': 'home'}], 'distance': 358}
# [0, 0, 1] [0, 0, 0]
#
# 401354473 top-1
# {'player': 'Anderson', 'type': 'homered', 'at': 'left center', 'runs': 1, 'distance': 395}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Pollock', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Grandal', 'type': 'lined out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Abreu', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Sheets', 'type': 'lined out', 'at': 'left'}
# [1, 0, 0] [1, 0, 0]
#
# 401354473 bottom-1
# {'player': 'Buxton', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Arraez', 'type': 'singled', 'at': 'shallow left center'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Polanco', 'type': 'grounded out', 'at': 'first', 'moves': [{'player': 'Arraez', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'player': 'Kepler', 'type': 'walked', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'player': 'Urshela', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Kepler', 'type': 'advanced', 'at': 'second'}, {'player': 'Arraez', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [1, 1, 1]
# {'player': 'Larnach', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [1, 1, 1] [1, 1, 1]
#
# 401354473 top-2
# {'outs': 1, 'player': 'Vaughn', 'type': 'grounded out', 'at': 'pitcher'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'García', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'type': 'throwing error', 'moves': [{'player': 'Haseley', 'type': 'advanced', 'at': 'first', 'how': 'throwing error', 'by': 'Sanó'}]}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Mendick', 'type': 'flied out', 'at': 'center'}
# [1, 0, 0] [1, 0, 0]
#
# 401354473 bottom-2
# {'player': 'Gordon', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Sanó', 'type': 'singled', 'at': 'right'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Godoy', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Buxton', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
#
# 401354473 top-3
# {'player': 'Anderson', 'type': 'singled', 'at': 'right'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Pollock', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
# {'type': 'stole', 'moves': [{'player': 'Anderson', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'player': 'Grandal', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 1, 0] [0, 1, 0]
# {'player': 'Abreu', 'type': 'walked', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'player': 'Sheets', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Abreu', 'type': 'advanced', 'at': 'second'}, {'player': 'Anderson', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [1, 1, 1]
# {'player': 'Vaughn', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'Anderson', 'type': 'advanced', 'at': 'home'}, {'player': 'Sheets', 'type': 'advanced', 'at': 'second'}, {'player': 'Abreu', 'type': 'out', 'at': 'home'}], 'outs': 1, 'runs': 1}
# [1, 1, 1] [1, 1, 0]
#
# 401354473 bottom-3
# {'player': 'Arraez', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Polanco', 'type': 'singled', 'at': 'right', 'moves': [{'player': 'Arraez', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'player': 'Kepler', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'Polanco', 'type': 'advanced', 'at': 'second'}, {'player': 'Arraez', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [1, 1, 1]
# {'player': 'Urshela', 'type': 'sacrifice fly', 'at': 'center', 'outs': 1, 'moves': [{'player': 'Arraez', 'type': 'advanced', 'at': 'home'}, {'player': 'Kepler', 'type': 'advanced', 'at': 'second'}, {'player': 'Polanco', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 1, 1] [0, 1, 1]
# {'player': 'Larnach', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 1, 1] [0, 1, 1]
# {'player': 'Gordon', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 1, 1] [0, 1, 1]
#
# 401354473 top-4
# {'outs': 1, 'player': 'García', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Haseley', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Mendick', 'type': 'singled', 'at': 'left'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Anderson', 'type': 'flied out', 'at': 'right'}
# [1, 0, 0] [1, 0, 0]
#
# 401354473 bottom-4
# {'outs': 1, 'player': 'Sanó', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Godoy', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Buxton', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
#
# 401354473 top-5
# ...
# [0, 0, 0] [0, 0, 0]
# {'player': 'Buxton', 'type': 'homered', 'at': 'left', 'runs': 1, 'distance': 438}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Polanco', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Miranda', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
#
# 401355719 bottom-4
# {'player': 'Voit', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Hosmer', 'type': 'homered', 'at': 'center', 'runs': 1, 'distance': 410}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Alfaro', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Mazara', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
#
# 401355719 top-5
# {'player': 'Arraez', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Sánchez', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Arraez', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'player': 'Sanó', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 1, 0] [1, 1, 0]
# {'player': 'Celestino', 'type': 'grounded into double play', 'outs': 2, 'order': ['shortstop', 'second', 'first'], 'moves': [{'player': 'Sánchez', 'type': 'out', 'at': 'second'}]}
# [1, 1, 0] [0, 1, 0]
#
# 401355719 bottom-5
# {'player': 'Kim', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Grisham', 'type': 'struck out', 'outs': 1, 'effort': 'bunting foul'}
# [1, 0, 0] [1, 0, 0]
# {'type': 'stole', 'moves': [{'player': 'Kim', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Profar', 'type': 'flied out', 'at': 'center'}
# [0, 1, 0] [0, 1, 0]
# {'player': 'Machado', 'type': 'homered', 'at': 'left', 'runs': 2, 'moves': [{'player': 'Kim', 'type': 'advanced', 'at': 'home'}], 'distance': 363}
# [0, 1, 0] [0, 0, 0]
# {'player': 'Cronenworth', 'type': 'singled', 'at': 'right'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Voit', 'type': 'doubled', 'at': 'left', 'moves': [{'player': 'Cronenworth', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
# [1, 0, 0] [0, 1, 0]
# {'player': 'Hosmer', 'type': 'walked', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'player': 'Alfaro', 'type': 'homered', 'at': 'right', 'runs': 3, 'moves': [{'player': 'Voit', 'type': 'advanced', 'at': 'home'}, {'player': 'Hosmer', 'type': 'advanced', 'at': 'home'}], 'distance': 373}
# [1, 1, 0] [0, 0, 0]
# {'player': 'Mazara', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
#
# 401355719 top-6
# {'player': 'Garlick', 'type': 'doubled', 'at': 'left center'}
# [0, 0, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Correa', 'type': 'flied out', 'at': 'center'}
# [0, 1, 0] [0, 1, 0]
# {'player': 'Buxton', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 1, 0] [0, 1, 0]
# {'player': 'Polanco', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 1, 0] [0, 1, 0]
#
# 401355719 bottom-6
# {'outs': 1, 'player': 'Kim', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Grisham', 'type': 'doubled', 'at': 'deep right'}
# [0, 0, 0] [0, 1, 0]
# {'player': 'Profar', 'type': 'walked', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'player': 'Moran', 'type': 'wild pitch', 'moves': [{'player': 'Profar', 'type': 'advanced', 'at': 'second', 'how': 'wild pitch', 'by': 'Moran'}, {'player': 'Grisham', 'type': 'advanced', 'at': 'third', 'how': 'wild pitch', 'by': 'Moran'}]}
# [1, 1, 0] [0, 1, 1]
# {'player': 'Machado', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 1, 1] [0, 1, 1]
# {'outs': 1, 'player': 'Cronenworth', 'type': 'lined out', 'at': 'right'}
# [0, 1, 1] [0, 1, 1]
#
# 401355719 top-7
# {'outs': 1, 'player': 'Miranda', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Arraez', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Sánchez', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
#
# 401355719 bottom-7
# {'player': 'Kirilloff', 'type': 'sub-f', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Kirilloff', 'type': 'sub-f', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Celestino', 'type': 'sub-f', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Voit', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Hosmer', 'type': 'grounded out', 'at': 'pitcher'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Alfaro', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
#
# 401355719 top-8
# {'player': 'Batten', 'type': 'sub-f', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Sanó', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Celestino', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Garlick', 'type': 'flied out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
#
# 401355719 bottom-8
# {'player': 'Polanco', 'type': 'sub-f', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Arraez', 'type': 'sub-f', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Sanó', 'type': 'sub-f', 'at': 'first'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Mazara', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Kim', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Grisham', 'type': 'fouled out', 'at': 'third'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Ruiz', 'type': 'sub-f', 'for': 'Profar'}
# [1, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Ruiz', 'type': 'popped out', 'at': 'first'}
# [1, 0, 0] [1, 0, 0]
#
# 401355719 top-9
# {'player': 'Ruiz', 'type': 'sub-f', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Kirilloff', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Gordon', 'type': 'doubled', 'at': 'left'}
# [0, 0, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Polanco', 'type': 'lined out', 'at': 'center'}
# [0, 1, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Miranda', 'type': 'popped out', 'at': 'third'}
# [0, 1, 0] [0, 1, 0]
#
# 401355689 top-1
# {'player': 'Anderson', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Moncada', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Pollock', 'type': 'grounded into double play', 'outs': 2, 'order': ['third', 'second', 'first'], 'moves': [{'player': 'Anderson', 'type': 'out', 'at': 'second'}]}
# [1, 0, 0] [0, 0, 0]
#
# 401355689 bottom-1
# {'player': 'Blackmon', 'type': 'homered', 'at': 'right', 'runs': 1, 'distance': 424}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Hampson', 'type': 'grounded out', 'at': 'pitcher'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Bryant', 'type': 'doubled', 'at': 'left'}
# [0, 0, 0] [0, 1, 0]
# {'player': 'Cron', 'type': 'singled', 'at': 'center', 'moves': [{'player': 'Bryant', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
# [0, 1, 0] [1, 0, 0]
# {'player': 'Rodgers', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Iglesias', 'type': 'doubled', 'at': 'deep center', 'moves': [{'player': 'Cron', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
# [1, 0, 0] [0, 1, 0]
# {'player': 'McMahon', 'type': 'walked', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'outs': 1, 'player': 'Díaz', 'type': 'grounded out', 'at': 'first'}
# [1, 1, 0] [1, 1, 0]
#
# 401355689 top-2
# {'outs': 1, 'player': 'Abreu', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Grandal', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Vaughn', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
#
# 401355689 bottom-2
# {'player': 'Daza', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Blackmon', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Hampson', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
#
# 401355689 top-3
# {'player': 'Harrison', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'García', 'type': 'grounded into double play', 'outs': 2, 'order': ['shortstop', 'first'], 'moves': [{'player': 'Harrison', 'type': 'out', 'at': 'second'}]}
# [1, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Zavala', 'type': 'lined out', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
#
# 401355689 bottom-3
# {'outs': 1, 'player': 'Bryant', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Cron', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Rodgers', 'type': 'singled', 'at': 'deep center'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Iglesias', 'type': 'grounded out', 'at': 'third'}
# [1, 0, 0] [1, 0, 0]
#
# 401355689 top-4
# {'outs': 1, 'player': 'Anderson', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Moncada', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Pollock', 'type': 'doubled', 'at': 'left', 'moves': [{'player': 'Moncada', 'type': 'advanced', 'at': 'third'}]}
# [1, 0, 0] [0, 1, 1]
# {'player': 'Abreu', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 1, 1] [0, 1, 1]
# {'player': 'Grandal', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'Moncada', 'type': 'advanced', 'at': 'home'}, {'player': 'Pollock', 'type': 'advanced', 'at': 'home'}], 'runs': 2}
# [0, 1, 1] [1, 0, 0]
# {'outs': 1, 'player': 'Vaughn', 'type': 'lined out', 'at': 'third'}
# [1, 0, 0] [1, 0, 0]
#
# 401355689 bottom-4
# {'player': 'McMahon', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Díaz', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'McMahon', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'player': 'Daza', 'type': "grounded into fielder's choice", 'at': 'shortstop', 'moves': [{'player': 'Díaz', 'type': 'out', 'at': 'second'}, {'player': 'McMahon', 'type': 'advanced', 'at': 'third'}], 'outs': 1}
# [1, 1, 0] [1, 0, 1]
# {'player': 'Blackmon', 'type': 'grounded into double play', 'outs': 2, 'order': ['shortstop', 'first'], 'moves': [{'player': 'Daza', 'type': 'out', 'at': 'second'}]}
# [1, 0, 1] [0, 0, 1]
#
# 401355689 top-5
# {'outs': 1, 'player': 'Harrison', 'type': 'flied out', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'García', 'type': 'struck out', 'moves': [{'player': 'García', 'type': 'advanced', 'at': 'first', 'how': 'wild pitch', 'by': 'Senzatela'}]}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Zavala', 'type': 'singled', 'at': 'right', 'moves': [{'player': 'García', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'outs': 1, 'player': 'Anderson', 'type': 'grounded out', 'at': 'shortstop', 'moves': [{'player': 'Zavala', 'type': 'advanced', 'at': 'second'}, {'player': 'García', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [0, 1, 1]
# {'player': 'Moncada', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'García', 'type': 'out', 'at': 'third'}], 'outs': 1}
# [0, 1, 1] [1, 1, 0]
#
# 401355689 bottom-5
# {'player': 'Hampson', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Bryant', 'type': 'singled', 'at': 'shallow center'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Cron', 'type': 'grounded out', 'at': 'second', 'moves': [{'player': 'Bryant', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'player': 'Rodgers', 'type': 'walked', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'outs': 1, 'player': 'Iglesias', 'type': 'lined out', 'at': 'center'}
# [1, 1, 0] [1, 1, 0]
#
# 401355689 top-6
# {'outs': 1, 'player': 'Pollock', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Abreu', 'type': 'doubled', 'at': 'deep left center'}
# [0, 0, 0] [0, 1, 0]
# {'player': 'Grandal', 'type': 'lined into double play', 'outs': 2, 'order': ['second', 'shortstop'], 'moves': [{'player': 'Abreu', 'type': 'out', 'at': 'second'}]}
# [0, 1, 0] [0, 0, 0]
#
# 401355689 bottom-6
# {'player': 'McMahon', 'type': 'singled', 'at': 'left'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Díaz', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'McMahon', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'outs': 1, 'player': 'Daza', 'type': 'grounded out', 'at': 'shortstop', 'moves': [{'player': 'Díaz', 'type': 'advanced', 'at': 'second'}, {'player': 'McMahon', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [0, 1, 1]
# {'player': 'Blackmon', 'type': 'intentionally walked', 'at': 'first'}
# [0, 1, 1] [1, 1, 1]
# {'player': 'Hampson', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 1, 1] [1, 1, 1]
# {'outs': 1, 'player': 'Bryant', 'type': 'flied out', 'at': 'center'}
# [1, 1, 1] [1, 1, 1]
#
# 401355689 top-7
# {'player': 'Vaughn', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Harrison', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'García', 'type': 'infield single', 'at': 'pitcher'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Zavala', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'García', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'player': 'Anderson', 'type': 'singled', 'at': 'left center', 'moves': [{'player': 'García', 'type': 'advanced', 'at': 'home'}, {'player': 'Zavala', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 1, 0] [1, 0, 1]
# {'player': 'Moncada', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Anderson', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 1] [1, 1, 1]
# {'player': 'Pollock', 'type': 'singled', 'at': 'right', 'moves': [{'player': 'Anderson', 'type': 'advanced', 'at': 'home'}, {'player': 'Zavala', 'type': 'advanced', 'at': 'home'}, {'player': 'Moncada', 'type': 'advanced', 'at': 'third'}], 'runs': 2}
# [1, 1, 1] [1, 0, 1]
# {'player': 'Abreu', 'type': "grounded into fielder's choice", 'at': 'second', 'moves': [{'player': 'Pollock', 'type': 'out', 'at': 'second'}], 'outs': 1}
# [1, 0, 1] [1, 0, 1]
#
# 401355689 bottom-7
# {'player': 'Cron', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Rodgers', 'type': 'doubled', 'at': 'deep center'}
# [0, 0, 0] [0, 1, 0]
# {'player': 'Iglesias', 'type': 'singled', 'at': 'right', 'moves': [{'player': 'Rodgers', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
# [0, 1, 0] [1, 0, 0]
# {'outs': 1, 'player': 'McMahon', 'type': 'lined out', 'at': 'right'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Díaz', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
#
# 401355689 top-8
# {'outs': 1, 'player': 'Grandal', 'type': 'grounded out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Vaughn', 'type': 'flied out', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Harrison', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
#
# 401355689 bottom-8
# {'player': 'Engel', 'type': 'sub-f', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'García', 'type': 'sub-f', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Daza', 'type': 'doubled', 'at': 'right'}
# [0, 0, 0] [0, 1, 0]
# {'player': 'Blackmon', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 1, 0] [0, 1, 0]
# {'player': 'Hampson', 'type': 'hit by pitch', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'player': 'Bryant', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 1, 0] [1, 1, 0]
# {'outs': 1, 'player': 'Cron', 'type': 'fouled out', 'at': 'shortstop'}
# [1, 1, 0] [1, 1, 0]
#
# 401355689 top-9
# {'outs': 1, 'player': 'García', 'type': 'grounded out', 'at': 'catcher'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Zavala', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Anderson', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
#
# 401355689 bottom-9
# {'player': 'Rodgers', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Iglesias', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Rodgers', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'player': 'McMahon', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Iglesias', 'type': 'advanced', 'at': 'second'}, {'player': 'Rodgers', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [1, 1, 1]
# {'player': 'Díaz', 'type': 'singled', 'at': 'right', 'moves': [{'player': 'Iglesias', 'type': 'advanced', 'at': 'home'}, {'player': 'Rodgers', 'type': 'advanced', 'at': 'home'}, {'player': 'McMahon', 'type': 'advanced', 'at': 'second'}], 'runs': 2}
# [1, 1, 1] [1, 1, 0]
