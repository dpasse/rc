# %%
import os
import sys
import json
from collections import defaultdict
import pandas as pd

import sys
sys.path.insert(0, '../../../pipelines/tasks/mlb/')

from common.pbp.models import Game
from common.pbp.context import BasesContext

# %%
games = []
for file in os.listdir('../../../data/mlb/pbp/2/'):
    with open(f'../../../data/mlb/pbp/2/{file}', 'r', encoding='UTF8') as pbp_input:
        game = Game(json.load(pbp_input))

    games.append(game)

# %%
import numpy as np

for game in games:
    for period in game.periods:
        for event in period.events:
            if len(event.pitch_events) > 0:
                print(game.id, period.id, event.id)
                print(np.array(event.pitches))
                print(event.entities.body)
                print()
# Out:
# 401354266 bottom-6 64
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="63" desc="Candelario to third, Báez out at home on runner's fielder's choice." /> /> />]
# {'player': 'Cabrera', 'type': 'walked', 'at': 'first'}
#
# 401354266 top-7 74
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="73" desc="Robert stole second." /> /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="8"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Abreu', 'type': "grounded into fielder's choice", 'at': 'third', 'moves': [{'player': 'Engel', 'type': 'out', 'at': 'home'}], 'outs': 1}
#
# 401354268 bottom-7 66
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=<Event id="65" desc="Olivares stole second." /> /> />]
# {'player': 'Mondesi', 'type': 'walked', 'at': 'first'}
#
# 401354277 top-2 16
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="15" desc="Kelenic stole second." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Rodríguez', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
#
# 401354277 top-6 59
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=<Event id="58" desc="Kelenic picked off first." /> />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />                                           ]
# {'player': 'Caleb Thielbar', 'type': 'pitches', 'to': 'Julio Rodriguez', 'premature': True}
#
# 401354281 top-1 5
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="4" desc="Robert stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="8"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="9"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Abreu', 'type': 'grounded out', 'at': 'second', 'moves': [{'player': 'Anderson', 'type': 'advanced', 'at': 'home'}, {'player': 'Robert', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
#
# 401354281 bottom-1 13
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="12" desc="Meadows caught stealing second, catcher to shortstop." /> /> />]
# {'player': 'Michael Kopech', 'type': 'pitches', 'to': 'Jeimer Candelario', 'premature': True}
#
# 401354281 top-4 44
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=<Event id="43" desc="Mendick out at home on runner's fielder's choice." /> /> />]
# {'player': 'Tarik Skubal', 'type': 'pitches', 'to': 'Jose Abreu', 'premature': True}
#
# 401354292 bottom-7 78
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="77" desc="Urshela to second on wild pitch by Ramirez." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Sanó', 'type': 'fouled out', 'at': 'first'}
#
# 401354295 top-1 4
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="3" desc="Straw stole second." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Kwan', 'type': 'walked', 'at': 'first'}
#
# 401354295 bottom-1 13
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="12" desc="Merrifield stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Benintendi', 'type': 'walked', 'at': 'first'}
#
# 401354295 bottom-3 35
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="34" desc="Witt Jr. stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Benintendi', 'type': 'walked', 'at': 'first'}
#
# 401354295 bottom-4 48
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="47" desc="Mondesi stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Taylor', 'type': 'walked', 'at': 'first'}
#
# 401354303 top-3 25
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="24" desc="Rodríguez stole second, Rodríguez safe at third on throwing error by catcher Sánchez." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'player': 'Raleigh', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401354303 bottom-6 66
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="65" desc="Buxton stole second." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="8"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />]
# {'player': 'Correa', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401354306 top-6 55
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="54" desc="Devers to second on wild pitch by Barnes." /> /> />]
# {'outs': 1, 'player': 'Bogaerts', 'type': 'flied out', 'at': 'shortstop'}
#
# 401354306 top-8 77
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="76" desc="Hernández to second on wild pitch by Lange." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Devers', 'type': 'singled', 'at': 'center', 'moves': [{'player': 'Hernández', 'type': 'advanced', 'at': 'home', 'how': 'error'}, {'player': 'Devers', 'type': 'advanced', 'at': 'second', 'how': 'fielding error', 'by': 'Baddoo'}], 'runs': 1}
#
# 401354308 top-1 5
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="4" desc="Kwan caught stealing second, catcher to shortstop." /> /> />]
# {'player': 'Ramírez', 'type': 'singled', 'at': 'center'}
#
# 401354308 top-1 7
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="6" desc="Ramírez caught stealing second, catcher to second." /> /> />]
# {'player': 'Tyler Mahle', 'type': 'pitches', 'to': 'Franmil Reyes', 'premature': True}
#
# 401354308 top-6 55
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=<Event id="54" desc="Rosario caught stealing second, catcher to second." /> /> />]
# {'outs': 1, 'player': 'Miller', 'type': 'flied out', 'at': 'right'}
#
# 401354308 top-7 71
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="70" desc="Straw stole second." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Kwan', 'type': 'grounded out', 'at': 'second'}
#
# 401354308 bottom-9 100
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="98" desc="Naquin to third on wild pitch by Hentges." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=<Event id="99" desc="Naquin scored on Hentges wild pitch." /> /> />]
# {'player': 'Aquino', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401354312 top-5 41
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="40" desc="Bellinger stole second." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Taylor', 'type': 'walked', 'at': 'first'}
#
# 401354312 top-5 43
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=<Event id="42" desc="Taylor stole second, Bellinger stole third." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'player': 'Lux', 'type': 'sacrifice fly', 'at': 'center', 'outs': 1, 'moves': [{'player': 'Bellinger', 'type': 'advanced', 'at': 'home'}, {'player': 'Taylor', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
#
# 401354312 top-9 106
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="105" desc="Muncy to second on wild pitch by Cotton." /> /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'J. Turner', 'type': 'walked', 'at': 'first'}
#
# 401354318 top-5 46
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="45" desc="France to second on wild pitch by Sousa." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Winker', 'type': 'walked', 'at': 'first'}
#
# 401354318 bottom-6 64
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="63" desc="Abreu to second on wild pitch by Festa." /> /> />]
# {'player': 'Jiménez', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401354318 bottom-8 86
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="85" desc="Robert stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Abreu', 'type': 'walked', 'at': 'first'}
#
# 401354318 bottom-8 88
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=<Event id="87" desc="Robert stole third." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Grandal', 'type': 'fouled out', 'at': 'third'}
#
# 401354323 bottom-3 37
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="36" desc="Naquin stole second." /> /> />]
# {'player': 'Stephenson', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401354323 top-4 41
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="40" desc="Straw stole second." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Kwan', 'type': 'grounded out', 'at': 'pitcher', 'moves': [{'player': 'Straw', 'type': 'advanced', 'at': 'third'}]}
#
# 401354326 top-1 6
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="5" desc="T. Turner stole second." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 1]" pitch_event=None /> />]
# {'player': 'Muncy', 'type': 'hit by pitch', 'at': 'first'}
#
# 401354331 bottom-2 20
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="19" desc="Vaughn to second on wild pitch by Ray." /> /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Engel', 'type': 'walked', 'at': 'first'}
#
# 401354331 top-9 95
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="94" desc="Suárez to third on passed ball by Grandal." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />]
# {'player': 'Crawford', 'type': 'infield single', 'at': 'shortstop', 'moves': [{'player': 'Suárez', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
#
# 401354338 bottom-2 23
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="22" desc="Mondesi stole second." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />]
# {'player': 'Taylor', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401354338 bottom-4 43
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="42" desc="Mondesi stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Taylor', 'type': 'infield single', 'at': 'third', 'moves': [{'player': 'Dozier', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
#
# 401354338 bottom-4 47
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=<Event id="46" desc="Merrifield stole second." /> /> />]
# {'player': 'Witt Jr.', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
#
# 401354338 top-6 59
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="58" desc="Meadows to second on wild pitch by Greinke." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Schoop', 'type': 'grounded out', 'at': 'third'}
#
# 401354341 top-2 16
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="15" desc="Rodríguez stole second." /> /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />]
# {'type': 'fielding error', 'moves': [{'player': 'Raleigh', 'type': 'advanced', 'at': 'first', 'how': 'fielding error', 'by': 'García'}, {'player': 'Rodríguez', 'type': 'advanced', 'at': 'third'}]}
#
# 401354341 top-8 81
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=<Event id="80" desc="Kelenic stole second." /> /> />]
# {'player': 'Rodríguez', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
#
# 401354352 top-3 29
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="28" desc="Kepler stole second." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Sánchez', 'type': 'flied out', 'at': 'right', 'moves': [{'player': 'Kepler', 'type': 'advanced', 'at': 'third'}]}
#
# 401354352 top-4 40
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="39" desc="Sanó stole second." /> /> />]
# {'outs': 1, 'player': 'Arraez', 'type': 'grounded out', 'at': 'second'}
#
# 401354352 top-6 64
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="63" desc="Arraez caught stealing second, catcher to second." /> /> />]
# {'player': 'Hirokazu Sawamura', 'type': 'pitches', 'to': 'Carlos Correa', 'premature': True}
#
# 401354356 top-7 65
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="64" desc="Yastrzemski to second on wild pitch by Gose." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Ruf', 'type': 'walked', 'at': 'first'}
#
# 401354358 top-1 6
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="5" desc="Franco out at second on runner's fielder's choice." /> /> />]
# {'player': 'Dylan Cease', 'type': 'pitches', 'to': 'Ji-Man Choi', 'premature': True}
#
# 401354358 bottom-1 12
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="11" desc="Anderson stole second." /> /> />]
# {'outs': 1, 'player': 'Grandal', 'type': 'grounded out', 'at': 'shortstop'}
#
# 401354358 bottom-2 22
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=<Event id="21" desc="Sheets scored on Rasmussen wild pitch." /> /> />]
# {'player': 'Vaughn', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
#
# 401354358 bottom-5 53
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="52" desc="Burger to second on wild pitch by Rasmussen." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Robert', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401354358 top-7 72
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="71" desc="Margot stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Mejía', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401354358 bottom-7 80
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="79" desc="Engel to second on passed ball by Mejía." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Burger', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401354365 top-2 17
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="16" desc="Cameron stole second." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Garneau', 'type': 'doubled', 'at': 'deep center', 'moves': [{'player': 'Cameron', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
#
# 401354371 top-3 24
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="23" desc="Duggar stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Bart', 'type': 'grounded out', 'at': 'third'}
#
# 401354371 bottom-6 68
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="67" desc="Rosario stole second." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Naylor', 'type': 'walked', 'at': 'first'}
#
# 401354371 top-8 88
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="87" desc="Slater scored on Sandlin wild pitch, Williams to second on wild pitch by Sandlin." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Estrada', 'type': 'fouled out', 'at': 'third'}
#
# 401354371 top-9 98
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="97" desc="Bart stole second." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Yastrzemski', 'type': 'lined out', 'at': 'right', 'moves': [{'player': 'Bart', 'type': 'advanced', 'at': 'third'}]}
#
# 401354373 top-2 17
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="16" desc="Walls stole second." /> /> />]
# {'outs': 1, 'player': 'B. Lowe', 'type': 'flied out', 'at': 'center'}
#
# 401354373 bottom-4 38
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=<Event id="37" desc="Anderson to second on pickoff error by pitcher Kluber." /> />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
# ...
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="26" desc="Semien stole second." /> /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />]
# {'type': 'fielding error', 'moves': [{'player': 'García', 'type': 'advanced', 'at': 'first', 'how': 'fielding error', 'by': 'Rosario'}, {'player': 'Semien', 'type': 'advanced', 'at': 'third'}]}
#
# 401444866 top-3 29
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="28" desc="García stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Calhoun', 'type': 'grounded out', 'at': 'pitcher'}
#
# 401444866 bottom-3 34
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="33" desc="Rosario stole second." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />]
# {'player': 'Ramírez', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401444866 bottom-4 50
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="49" desc="Rosario stole second." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />]
# {'player': 'Ramírez', 'type': 'walked', 'at': 'first'}
#
# 401444866 bottom-6 72
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="71" desc="Rosario to second on wild pitch by Richards." /> /> />]
# {'outs': 1, 'player': 'Ramírez', 'type': 'flied out', 'at': 'center'}
#
# 401444866 bottom-7 85
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="84" desc="Mercado stole second." /> /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="8"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />]
# {'player': 'Giménez', 'type': 'infield single', 'at': 'pitcher', 'moves': [{'player': 'Mercado', 'type': 'advanced', 'at': 'home', 'how': 'fielding error', 'by': 'Semien'}], 'runs': 1}
#
# 401444866 bottom-8 96
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="95" desc="Straw stole second." /> /> />]
# {'outs': 1, 'player': 'Rosario', 'type': 'grounded out', 'at': 'third'}
#
# 401444866 bottom-8 99
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=<Event id="98" desc="Ramírez stole second, Straw stole third." /> /> />]
# {'outs': 1, 'player': 'Miller', 'type': 'popped out', 'at': 'second'}
#
# 401456485 bottom-1 10
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="9" desc="Rosario caught stealing second, catcher to shortstop." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />]
# {'player': 'Ramírez', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401456485 top-7 73
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="72" desc="Hicks to second on wild pitch by Castro." /> /> />]
# {'player': 'Carpenter', 'type': 'singled', 'at': 'right', 'moves': [{'player': 'Andújar', 'type': 'advanced', 'at': 'home'}, {'player': 'Hicks', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
#
# 401456485 bottom-7 83
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 1]" pitch_event=<Event id="82" desc="Straw stole second." /> /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />
#  <Pitch id="8"
#  prior=<BeforePitch bases="[0, 1, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Kwan', 'type': 'grounded out', 'at': 'shortstop', 'moves': [{'player': 'Palacios', 'type': 'advanced', 'at': 'home'}, {'player': 'Straw', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
#
# 401456485 top-8 89
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="88" desc="Judge stole second, LeMahieu stole third." /> /> />]
# {'player': 'Torres', 'type': "grounded into fielder's choice", 'at': 'shortstop', 'moves': [{'player': 'LeMahieu', 'type': 'advanced', 'at': 'home'}, {'player': 'Judge', 'type': 'out', 'at': 'third'}], 'outs': 1, 'runs': 1}
#
# 401463303 bottom-3 30
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="29" desc="Straw stole second." /> /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Rosario', 'type': 'flied out', 'at': 'right'}
#
# 401463303 bottom-5 50
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=<Event id="49" desc="Straw stole second." /> /> />]
# {'outs': 1, 'player': 'Rosario', 'type': 'grounded out', 'at': 'third'}
#
# 401463303 top-6 58
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="57" desc="Reyes stole second." /> /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'H. Castro', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401483570 bottom-8 84
# [<Pitch id="1"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=<Event id="83" desc="Peraza to second on pickoff error by pitcher López." /> />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="7"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />]
# {'player': 'Cabrera', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
#
# 401483570 bottom-9 97
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="96" desc="Locastro caught stealing second, catcher to second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=None /> />]
# {'player': 'Kiner-Falefa', 'type': 'singled', 'at': 'right'}
#
# 401483570 bottom-9 99
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="98" desc="Kiner-Falefa stole second, Kiner-Falefa safe at third on throwing error by catcher G. Sánchez." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />
#  <Pitch id="6"
#  prior=<BeforePitch bases="[0, 0, 1]" pitch_event=None />
#  result=<AfterPitch bases="[0, 0, 1]" pitch_event=None /> />]
# {'outs': 1, 'player': 'Florial', 'type': 'grounded out', 'at': 'shortstop'}
#
# 401483570 bottom-12 130
# [<Pitch id="1"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[1, 0, 0]" pitch_event=<Event id="129" desc="Kiner-Falefa stole second." /> /> />
#  <Pitch id="2"
#  prior=<BeforePitch bases="[1, 0, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="3"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="4"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 0]" pitch_event=None /> />
#  <Pitch id="5"
#  prior=<BeforePitch bases="[0, 1, 0]" pitch_event=None />
#  result=<AfterPitch bases="[0, 1, 1]" pitch_event=None /> />]
# {'player': 'Trevino', 'type': 'singled', 'at': 'right', 'moves': [{'player': 'Trevino', 'type': 'advanced', 'at': 'second'}, {'player': 'Kiner-Falefa', 'type': 'advanced', 'at': 'third'}]}

# %%
skip = [
    '401354253', 
    '401354268', 
    '401354277',
    '401354281',
    '401354266',
    '401354283',
    '401354292',
    '401354294',
    '401354295'
]

# %%
for game in games:
    if game.id in skip:
        continue
    
    for period in game.periods:

        context = BasesContext()

        print(game.id, period.id)

        for event in period.events:
            if event.entities.type in ['sub-p']:
                continue

            print(event.entities.body)
            state = context.play(event.entities)
            print(state.before, state.after)
            
            ##print(context.to_list(), event.last_pitch.result.bases if event.last_pitch else None)

        print()
# Out:
# 401354295 top-1
# {'player': 'Straw', 'type': 'infield single', 'at': 'catcher'}
# [0, 0, 0] [1, 0, 0]
# {'type': 'stole', 'moves': [{'player': 'Straw', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'player': 'Kwan', 'type': 'walked', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'player': 'Ramírez', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Kwan', 'type': 'advanced', 'at': 'second'}, {'player': 'Straw', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [1, 1, 1]
# {'player': 'Reyes', 'type': 'grounded into double play', 'outs': 2, 'order': ['shortstop', 'second', 'first'], 'moves': [{'player': 'Straw', 'type': 'advanced', 'at': 'home'}, {'player': 'Ramírez', 'type': 'out', 'at': 'second'}, {'player': 'Kwan', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 1, 1] [0, 0, 1]
# {'player': 'Rosario', 'type': 'infield single', 'at': 'second', 'moves': [{'player': 'Kwan', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
# [0, 0, 1] [1, 0, 0]
# {'outs': 1, 'player': 'Miller', 'type': 'grounded out', 'at': 'third'}
# [1, 0, 0] [1, 0, 0]
#
# 401354295 bottom-1
# {'player': 'Merrifield', 'type': 'singled', 'at': 'right'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Witt Jr.', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
# {'type': 'stole', 'moves': [{'player': 'Merrifield', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'player': 'Benintendi', 'type': 'walked', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'player': 'Perez', 'type': 'hit by pitch', 'at': 'first', 'moves': [{'player': 'Benintendi', 'type': 'advanced', 'at': 'second'}, {'player': 'Merrifield', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [1, 1, 1]
# {'player': 'Santana', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 1, 1] [1, 1, 1]
# {'outs': 1, 'player': 'Dozier', 'type': 'fouled out', 'at': 'first'}
# [1, 1, 1] [1, 1, 1]
#
# 401354295 top-2
# {'outs': 1, 'player': 'Mercado', 'type': 'flied out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Giménez', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Hedges', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Straw', 'type': 'flied out', 'at': 'center'}
# [1, 0, 0] [1, 0, 0]
#
# 401354295 bottom-2
# {'player': 'Mondesi', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Taylor', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Lopez', 'type': 'grounded out', 'at': 'pitcher'}
# [0, 0, 0] [0, 0, 0]
#
# 401354295 top-3
# {'outs': 1, 'player': 'Kwan', 'type': 'fouled out', 'at': 'catcher'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Ramírez', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Reyes', 'type': 'infield single', 'at': 'shortstop'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Rosario', 'type': "grounded into fielder's choice", 'at': 'shortstop', 'moves': [{'player': 'Reyes', 'type': 'out', 'at': 'second'}], 'outs': 1}
# [1, 0, 0] [1, 0, 0]
#
# 401354295 bottom-3
# {'player': 'Merrifield', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Witt Jr.', 'type': "grounded into fielder's choice", 'at': 'shortstop', 'moves': [{'player': 'Merrifield', 'type': 'out', 'at': 'second'}], 'outs': 1}
# [1, 0, 0] [1, 0, 0]
# {'type': 'stole', 'moves': [{'player': 'Witt Jr.', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'player': 'Benintendi', 'type': 'walked', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'player': 'Perez', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'Witt Jr.', 'type': 'advanced', 'at': 'home'}, {'player': 'Benintendi', 'type': 'advanced', 'at': 'second'}], 'runs': 1}
# [1, 1, 0] [1, 1, 0]
# {'outs': 1, 'player': 'Santana', 'type': 'flied out', 'at': 'right', 'moves': [{'player': 'Benintendi', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [1, 0, 1]
# {'outs': 1, 'player': 'Dozier', 'type': 'flied out', 'at': 'left'}
# [1, 0, 1] [1, 0, 1]
#
# 401354295 top-4
# {'player': 'Miller', 'type': 'doubled', 'at': 'right center'}
# [0, 0, 0] [0, 1, 0]
# {'player': 'Mercado', 'type': 'homered', 'at': 'left', 'runs': 2, 'moves': [{'player': 'Miller', 'type': 'advanced', 'at': 'home'}], 'distance': 403}
# [0, 1, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Giménez', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Hedges', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Straw', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
#
# 401354295 bottom-4
# {'player': 'Mondesi', 'type': 'singled', 'at': 'right'}
# [0, 0, 0] [1, 0, 0]
# {'type': 'stole', 'moves': [{'player': 'Mondesi', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'player': 'Taylor', 'type': 'walked', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'player': 'Lopez', 'type': "grounded into fielder's choice", 'at': 'third', 'moves': [{'player': 'Mondesi', 'type': 'advanced', 'at': 'home'}, {'player': 'Taylor', 'type': 'advanced', 'at': 'first', 'how': 'throwing error', 'by': 'Ramírez'}, {'player': 'Lopez', 'type': 'advanced', 'at': 'second'}, {'player': 'Taylor', 'type': 'advanced', 'at': 'third', 'how': 'error'}], 'runs': 1}
# [1, 1, 0] [0, 1, 1]
# {'outs': 1, 'player': 'Merrifield', 'type': 'grounded out', 'at': 'shortstop', 'moves': [{'player': 'Taylor', 'type': 'advanced', 'at': 'home'}, {'player': 'Lopez', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [0, 1, 1] [0, 0, 1]
# {'player': 'Witt Jr.', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 1] [0, 0, 1]
# {'player': 'Benintendi', 'type': 'singled', 'at': 'left center', 'moves': [{'player': 'Lopez', 'type': 'advanced', 'at': 'home'}], 'runs': 1}
# [0, 0, 1] [1, 0, 0]
# {'outs': 1, 'player': 'Perez', 'type': 'flied out', 'at': 'center'}
# [1, 0, 0] [1, 0, 0]
#
# 401354295 top-5
# {'outs': 1, 'player': 'Kwan', 'type': 'grounded out', 'at': 'pitcher'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Ramírez', 'type': 'popped out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Reyes', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
#
# 401354295 bottom-5
# {'outs': 1, 'player': 'Santana', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Dozier', 'type': 'hit by pitch', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Mondesi', 'type': 'grounded into double play', 'outs': 2, 'order': ['third', 'second', 'first'], 'moves': [{'player': 'Dozier', 'type': 'out', 'at': 'second'}]}
# [1, 0, 0] [0, 0, 0]
#
# 401354295 top-6
# {'outs': 1, 'player': 'Rosario', 'type': 'flied out', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Miller', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Mercado', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
#
# 401354295 bottom-6
# {'outs': 1, 'player': 'Taylor', 'type': 'popped out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Lopez', 'type': 'singled', 'at': 'left'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Merrifield', 'type': 'lined out', 'at': 'shortstop'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Witt Jr.', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
#
# 401354295 top-7
# {'player': 'Clement', 'type': 'sub-f', 'for': 'Giménez'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Clement', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Hedges', 'type': 'sacrificed', 'at': 'catcher', 'outs': 1, 'moves': [{'player': 'Clement', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [0, 1, 0]
# {'player': 'Straw', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 1, 0] [0, 1, 0]
# {'player': 'Kwan', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Clement', 'type': 'advanced', 'at': 'third', 'how': 'wild pitch', 'by': 'Brentz'}]}
# [0, 1, 0] [1, 0, 1]
# {'player': 'Ramírez', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'Clement', 'type': 'advanced', 'at': 'home'}, {'player': 'Kwan', 'type': 'advanced', 'at': 'second'}], 'runs': 1}
# [1, 0, 1] [1, 1, 0]
# {'player': 'Reyes', 'type': 'singled', 'at': 'shallow right', 'moves': [{'player': 'Kwan', 'type': 'advanced', 'at': 'home'}, {'player': 'Ramírez', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 1, 0] [1, 0, 1]
# {'player': 'Rosario', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 1] [1, 0, 1]
#
# 401354295 bottom-7
# {'player': 'Clement', 'type': 'sub-f', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Benintendi', 'type': 'singled', 'at': 'right'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Perez', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'Benintendi', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'player': 'Santana', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Perez', 'type': 'advanced', 'at': 'second'}, {'player': 'Benintendi', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [1, 1, 1]
# {'player': 'Dozier', 'type': "hit into fielder's choice", 'at': 'center', 'moves': [{'player': 'Benintendi', 'type': 'advanced', 'at': 'home'}, {'player': 'Santana', 'type': 'out', 'at': 'second'}, {'player': 'Perez', 'type': 'advanced', 'at': 'third'}], 'outs': 1, 'runs': 1}
# [1, 1, 1] [1, 0, 1]
# {'player': 'Mondesi', 'type': 'grounded into double play', 'outs': 2, 'order': ['second', 'shortstop', 'first'], 'moves': [{'player': 'Dozier', 'type': 'out', 'at': 'second'}]}
# [1, 0, 1] [0, 0, 1]
#
# 401354295 top-8
# {'player': 'Miller', 'type': 'doubled', 'at': 'deep left'}
# [0, 0, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Mercado', 'type': 'lined out', 'at': 'right'}
# [0, 1, 0] [0, 1, 0]
# {'player': 'Clement', 'type': 'walked', 'at': 'first'}
# [0, 1, 0] [1, 1, 0]
# {'outs': 1, 'player': 'Hedges', 'type': 'flied out', 'at': 'right', 'moves': [{'player': 'Miller', 'type': 'advanced', 'at': 'third'}]}
# [1, 1, 0] [1, 0, 1]
# {'player': 'Straw', 'type': 'walked', 'at': 'first', 'moves': [{'player': 'Clement', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 1] [1, 1, 1]
# {'player': 'Kwan', 'type': 'tripled', 'at': 'deep right', 'moves': [{'player': 'Miller', 'type': 'advanced', 'at': 'home'}, {'player': 'Clement', 'type': 'advanced', 'at': 'home'}, {'player': 'Straw', 'type': 'advanced', 'at': 'home'}], 'runs': 3}
# [1, 1, 1] [0, 0, 1]
# {'outs': 1, 'player': 'Ramírez', 'type': 'grounded out', 'at': 'first'}
# [0, 0, 1] [0, 0, 1]
#
# 401354295 bottom-8
# {'player': 'Taylor', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Lopez', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Merrifield', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
#
# 401354295 top-9
# {'outs': 1, 'player': 'Reyes', 'type': 'popped out', 'at': 'second'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Rosario', 'type': 'singled', 'at': 'center'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Miller', 'type': 'singled', 'at': 'center', 'moves': [{'player': 'Rosario', 'type': 'advanced', 'at': 'third'}]}
# [1, 0, 0] [1, 0, 1]
# {'outs': 1, 'player': 'Mercado', 'type': 'grounded out', 'at': 'third', 'moves': [{'player': 'Rosario', 'type': 'advanced', 'at': 'home'}, {'player': 'Miller', 'type': 'advanced', 'at': 'second'}], 'runs': 1}
# [1, 0, 1] [0, 1, 0]
# {'outs': 1, 'player': 'Clement', 'type': 'flied out', 'at': 'right'}
# [0, 1, 0] [0, 1, 0]
#
# 401354295 bottom-9
# {'player': 'Witt Jr.', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Benintendi', 'type': 'homered', 'at': 'right center', 'runs': 2, 'moves': [{'player': 'Witt Jr.', 'type': 'advanced', 'at': 'home'}], 'distance': 407}
# [1, 0, 0] [0, 0, 0]
# {'player': 'Perez', 'type': 'struck out', 'outs': 1, 'effort': 'looking'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Santana', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Dozier', 'type': 'lined out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
#
# 401354303 top-1
# {'outs': 1, 'player': 'Frazier', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'France', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Winker', 'type': 'flied out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
#
# 401354303 bottom-1
# {'player': 'Buxton', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Correa', 'type': 'flied out', 'at': 'center'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Arraez', 'type': 'singled', 'at': 'left', 'moves': [{'player': 'Buxton', 'type': 'advanced', 'at': 'second'}]}
# [1, 0, 0] [1, 1, 0]
# {'player': 'Polanco', 'type': 'doubled', 'at': 'deep right', 'moves': [{'player': 'Buxton', 'type': 'advanced', 'at': 'home'}, {'player': 'Arraez', 'type': 'advanced', 'at': 'third'}], 'runs': 1}
# [1, 1, 0] [0, 1, 1]
# {'outs': 1, 'player': 'Urshela', 'type': 'flied out', 'at': 'center'}
# [0, 1, 1] [0, 1, 1]
# {'outs': 1, 'player': 'Kepler', 'type': 'grounded out', 'at': 'second'}
# [0, 1, 1] [0, 1, 1]
#
# 401354303 top-2
# {'outs': 1, 'player': 'Haniger', 'type': 'lined out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Toro', 'type': 'flied out', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Suárez', 'type': 'doubled', 'at': 'shallow left'}
# [0, 0, 0] [0, 1, 0]
# {'outs': 1, 'player': 'Crawford', 'type': 'flied out', 'at': 'left'}
# [0, 1, 0] [0, 1, 0]
#
# 401354303 bottom-2
# {'outs': 1, 'player': 'Sánchez', 'type': 'flied out', 'at': 'right'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Sanó', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'player': 'Kirilloff', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [1, 0, 0] [1, 0, 0]
# {'player': 'Buxton', 'type': 'doubled', 'at': 'deep left', 'moves': [{'player': 'Sanó', 'type': 'out', 'at': 'home'}], 'outs': 1}
# [1, 0, 0] [0, 1, 0]
#
# 401354303 top-3
# {'player': 'Rodríguez', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'type': 'stole', 'moves': [{'player': 'Rodríguez', 'type': 'advanced', 'at': 'second'}, {'player': 'Rodríguez', 'type': 'advanced', 'at': 'third', 'how': 'throwing error', 'by': 'Sánchez'}]}
# [1, 0, 0] [0, 0, 1]
# {'player': 'Raleigh', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 1] [0, 0, 1]
# {'outs': 1, 'player': 'Frazier', 'type': 'flied out', 'at': 'center'}
# [0, 0, 1] [0, 0, 1]
# {'outs': 1, 'player': 'France', 'type': 'lined out', 'at': 'left'}
# [0, 0, 1] [0, 0, 1]
#
# 401354303 bottom-3
# {'player': 'Correa', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Arraez', 'type': 'flied out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Polanco', 'type': 'walked', 'at': 'first'}
# [0, 0, 0] [1, 0, 0]
# {'outs': 1, 'player': 'Urshela', 'type': 'flied out', 'at': 'right'}
# [1, 0, 0] [1, 0, 0]
#
# 401354303 top-4
# {'outs': 1, 'player': 'Winker', 'type': 'grounded out', 'at': 'shortstop'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Haniger', 'type': 'fouled out', 'at': 'first'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Toro', 'type': 'grounded out', 'at': 'third'}
# [0, 0, 0] [0, 0, 0]
#
# 401354303 bottom-4
# {'outs': 1, 'player': 'Kepler', 'type': 'flied out', 'at': 'left'}
# [0, 0, 0] [0, 0, 0]
# {'player': 'Sánchez', 'type': 'struck out', 'outs': 1, 'effort': 'swinging'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Sanó', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
#
# 401354303 top-5
# {'outs': 1, 'player': 'Suárez', 'type': 'flied out', 'at': 'center'}
# [0, 0, 0] [0, 0, 0]
# {'outs': 1, 'player': 'Crawford', 'type': 'grounded out', 'at': 'first'}
# [0, 0, 0] [0, 0, 0]
# {'type': 'throwing error', 'moves': [{'player': 'Rodríguez', 'type': 'advanced', 'at': 'first', 'how': 'throwing error', 'by': 'Correa'}]}
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 16
#      13     continue
#      15 print(event.entities.body)
# ---> 16 state = context.play(event.entities)
#      17 print(state.before, state.after)
#      19 ##print(context.to_list(), event.last_pitch.result.bases if event.last_pitch else None)
#
# File c:\Users\dmpas\Documents\GitHub\rc\pipelines\tasks\mlb\common\pbp\context.py:107, in BasesContext.play(self, entities)
#     105 for move in entities.moves:
#     106     if move.type == 'advanced':
# --> 107         assert self.get(move.body['player']) ## events are out of order
#     108         self.add(move.body['player'], move.at)
#     110     if move.type == 'out':
#
# AssertionError:

# %%
401354253
401354277
