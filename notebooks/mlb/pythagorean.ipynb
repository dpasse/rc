# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

status_codes = requests.status_codes.codes

# %% [markdown]
# ### The Pythagorean Theorem of Baseball
#
# > "The Pythagorean Theorem of Baseball is a creation of Bill James which relates the number of runs a team has scored and surrendered to its actual winning percentage, based on the idea that runs scored compared to runs allowed is a better indicator of a team's (future) performance than a team's actual winning percentage." - [Pythagorean Theorem of Baseball - Baseball Reference](https://www.baseball-reference.com/bullpen/Pythagorean_Theorem_of_Baseball)

# %%
def pythagorean(rs, ra, exp):
    rate = (rs / ra) ** exp
    return round(rate / (rate + 1), 3)

def parse_standings_table(content):
    teams = []
    stats = []

    standings = BeautifulSoup(content).select('.standings__table')
    for standing in standings:
        rows = standing.select('tbody.Table__TBODY')

        for row in rows[0].select('tr'):
            if 'subgroup-headers' in row.attrs['class']:
                continue

            teams.append(row.select('td .AnchorLink abbr')[0].attrs['title'])

        for row in rows[1].select('tr'):
            if 'subgroup-headers' in row.attrs['class']:
                continue

            columns = row.select('td')

            pct = float(columns[2].text)
            rs = int(columns[6].text)
            ra = int(columns[7].text)

            py_2 = pythagorean(rs, ra, 2)
            py_181 = pythagorean(rs, ra, 1.81)
            py_183 = pythagorean(rs, ra, 1.83)

            diff_2 = round(pct - py_2, 3)
            diff_181 = round(pct - py_181, 3)
            diff_183 = round(pct - py_183, 3)

            stats.append({ 'rs': rs, 'ra': ra, 'wpct': pct, 'py_2': py_2, 'py_181': py_181, 'py_183': py_183, 'diff_py_2': diff_2, 'diff_py_181': diff_181, 'diff_py_183': diff_183 })

    data = dict(zip(teams, stats))
    return pd.DataFrame(data).T

# %%
response = requests.get('https://www.espn.com/mlb/standings')

if response.status_code != status_codes['ok']:
    raise Exception('no!!!!')

df = parse_standings_table(response.content)

# %%
df
# Out:
#                           rs     ra   wpct   py_2  py_181  py_183  diff_py_2  \
# New York Yankees       807.0  567.0  0.611  0.670   0.654   0.656     -0.059
# Toronto Blue Jays      775.0  679.0  0.568  0.566   0.560   0.560      0.002
# Tampa Bay Rays         666.0  614.0  0.531  0.541   0.537   0.537     -0.010
# Baltimore Orioles      674.0  688.0  0.512  0.490   0.491   0.491      0.022
# Boston Red Sox         735.0  787.0  0.481  0.466   0.469   0.469      0.015
# Cleveland Guardians    698.0  634.0  0.568  0.548   0.543   0.544      0.020
# Chicago White Sox      686.0  717.0  0.500  0.478   0.480   0.480      0.022
# Minnesota Twins        696.0  684.0  0.481  0.509   0.508   0.508     -0.028
# Detroit Tigers         557.0  713.0  0.407  0.379   0.390   0.389      0.028
# Kansas City Royals     640.0  810.0  0.401  0.384   0.395   0.394      0.017
# Houston Astros         737.0  518.0  0.654  0.669   0.654   0.656     -0.015
# Seattle Mariners       690.0  623.0  0.556  0.551   0.546   0.547      0.005
# Los Angeles Angels     623.0  668.0  0.451  0.465   0.468   0.468     -0.014
# Texas Rangers          707.0  743.0  0.420  0.475   0.478   0.477     -0.055
# Oakland Athletics      568.0  770.0  0.370  0.352   0.366   0.364      0.018
# Atlanta Braves         789.0  609.0  0.623  0.627   0.615   0.616     -0.004
# New York Mets          772.0  606.0  0.623  0.619   0.608   0.609      0.004
# Philadelphia Phillies  747.0  685.0  0.537  0.543   0.539   0.540     -0.006
# Miami Marlins          586.0  676.0  0.426  0.429   0.436   0.435     -0.003
# Washington Nationals   603.0  855.0  0.340  0.332   0.347   0.345      0.008
# St. Louis Cardinals    772.0  637.0  0.574  0.595   0.586   0.587     -0.021
# Milwaukee Brewers      725.0  688.0  0.531  0.526   0.524   0.524      0.005
# Chicago Cubs           657.0  731.0  0.457  0.447   0.452   0.451      0.010
# Pittsburgh Pirates     591.0  817.0  0.383  0.344   0.358   0.356      0.039
# Cincinnati Reds        648.0  815.0  0.383  0.387   0.398   0.397     -0.004
# Los Angeles Dodgers    847.0  513.0  0.685  0.732   0.713   0.715     -0.047
# San Diego Padres       705.0  660.0  0.549  0.533   0.530   0.530      0.016
# San Francisco Giants   716.0  697.0  0.500  0.513   0.512   0.512     -0.013
# Arizona Diamondbacks   702.0  740.0  0.457  0.474   0.476   0.476     -0.017
# Colorado Rockies       698.0  873.0  0.420  0.390   0.400   0.399      0.030
#
#                        diff_py_181  diff_py_183
# New York Yankees            -0.043       -0.045
# Toronto Blue Jays            0.008        0.008
# Tampa Bay Rays              -0.006       -0.006
# Baltimore Orioles            0.021        0.021
# Boston Red Sox               0.012        0.012
# Cleveland Guardians          0.025        0.024
# Chicago White Sox            0.020        0.020
# Minnesota Twins             -0.027       -0.027
# Detroit Tigers               0.017        0.018
# Kansas City Royals           0.006        0.007
# Houston Astros               0.000       -0.002
# Seattle Mariners             0.010        0.009
# Los Angeles Angels          -0.017       -0.017
# Texas Rangers               -0.058       -0.057
# Oakland Athletics            0.004        0.006
# Atlanta Braves               0.008        0.007
# New York Mets                0.015        0.014
# Philadelphia Phillies       -0.002       -0.003
# Miami Marlins               -0.010       -0.009
# Washington Nationals        -0.007       -0.005
# St. Louis Cardinals         -0.012       -0.013
# Milwaukee Brewers            0.007        0.007
# Chicago Cubs                 0.005        0.006
# Pittsburgh Pirates           0.025        0.027
# Cincinnati Reds             -0.015       -0.014
# Los Angeles Dodgers         -0.028       -0.030
# San Diego Padres             0.019        0.019
# San Francisco Giants        -0.012       -0.012
# Arizona Diamondbacks        -0.019       -0.019
# Colorado Rockies             0.020        0.021
