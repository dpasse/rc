# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

status_codes = requests.status_codes.codes

# %% [markdown]
# ### The Pythagorean Theorem of Baseball
#
# > "The Pythagorean Theorem of Baseball is a creation of Bill James which relates the number of runs a team has scored and surrendered to its actual winning percentage, based on the idea that runs scored compared to runs allowed is a better indicator of a team's (future) performance than a team's actual winning percentage." - [Pythagorean Theorem of Baseball - Baseball Reference](https://www.baseball-reference.com/bullpen/Pythagorean_Theorem_of_Baseball)

# %%
columns = ['PYTH_2', 'PYTH_1_83']

df = pd.read_csv('../../data/mlb/standings.csv', index_col=None)
df['PCT'] = df['PCT'].astype(float)
df['season'] = df['season'].astype(str)

for column in columns:
    df[column] = df[column].astype(float)
    df[f'DIFF_{column}'] = (df['PCT'] - df[column]).round(3)

df = df.drop(columns=[
    'team',
    'GB',
    'HOME',
    'AWAY',
    'RS',
    'RA',
    'DIFF',
    'STRK',
    'L10'
])

df = df[['team_name', 'season', 'W', 'L', 'PCT'] + columns + [f'DIFF_{column}' for column in columns]]
df[df.season == '2022'].sort_values(['team_name'])
# Out:
#                 team_name season    W    L    PCT  PYTH_2  PYTH_1_83  \
# 80   Arizona Diamondbacks   2022   74   88  0.457   0.474      0.476
# 71         Atlanta Braves   2022  101   61  0.623   0.627      0.616
# 84      Baltimore Orioles   2022   83   79  0.512   0.490      0.491
# 83         Boston Red Sox   2022   78   84  0.481   0.466      0.469
# 72           Chicago Cubs   2022   74   88  0.457   0.447      0.451
# 81      Chicago White Sox   2022   81   81  0.500   0.478      0.480
# 66        Cincinnati Reds   2022   62  100  0.383   0.387      0.397
# 82    Cleveland Guardians   2022   92   70  0.568   0.548      0.544
# 89       Colorado Rockies   2022   68   94  0.420   0.390      0.399
# 79         Detroit Tigers   2022   66   96  0.407   0.379      0.389
# 77         Houston Astros   2022  106   56  0.654   0.669      0.656
# 78     Kansas City Royals   2022   65   97  0.401   0.384      0.394
# 75     Los Angeles Angels   2022   73   89  0.451   0.465      0.468
# 68    Los Angeles Dodgers   2022  111   51  0.685   0.732      0.715
# 62          Miami Marlins   2022   69   93  0.426   0.429      0.435
# 65      Milwaukee Brewers   2022   86   76  0.531   0.526      0.524
# 74        Minnesota Twins   2022   78   84  0.481   0.509      0.508
# 60          New York Mets   2022  101   61  0.623   0.619      0.609
# 87       New York Yankees   2022   99   63  0.611   0.670      0.656
# 73      Oakland Athletics   2022   60  102  0.370   0.352      0.364
# 61  Philadelphia Phillies   2022   87   75  0.537   0.543      0.540
# 67     Pittsburgh Pirates   2022   62  100  0.383   0.344      0.356
# 69       San Diego Padres   2022   89   73  0.549   0.533      0.530
# 70   San Francisco Giants   2022   81   81  0.500   0.513      0.512
# 76       Seattle Mariners   2022   90   72  0.556   0.551      0.547
# 64    St. Louis Cardinals   2022   93   69  0.574   0.595      0.587
# 85         Tampa Bay Rays   2022   86   76  0.531   0.541      0.537
# 88          Texas Rangers   2022   68   94  0.420   0.475      0.477
# 86      Toronto Blue Jays   2022   92   70  0.568   0.566      0.560
# 63   Washington Nationals   2022   55  107  0.340   0.332      0.345
#
#     DIFF_PYTH_2  DIFF_PYTH_1_83
# 80       -0.017          -0.019
# 71       -0.004           0.007
# 84        0.022           0.021
# 83        0.015           0.012
# 72        0.010           0.006
# 81        0.022           0.020
# 66       -0.004          -0.014
# 82        0.020           0.024
# 89        0.030           0.021
# 79        0.028           0.018
# 77       -0.015          -0.002
# 78        0.017           0.007
# 75       -0.014          -0.017
# 68       -0.047          -0.030
# 62       -0.003          -0.009
# 65        0.005           0.007
# 74       -0.028          -0.027
# 60        0.004           0.014
# 87       -0.059          -0.045
# 73        0.018           0.006
# 61       -0.006          -0.003
# 67        0.039           0.027
# 69        0.016           0.019
# 70       -0.013          -0.012
# 76        0.005           0.009
# 64       -0.021          -0.013
# 85       -0.010          -0.006
# 88       -0.055          -0.057
# 86        0.002           0.008
# 63        0.008          -0.005
